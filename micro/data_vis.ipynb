# %% [markdown]
# ### Data transformation and visualiztion note book
# #### Section micro

# %%
import pandas as pd
import numpy as np

# %%
# get the data
a = pd.read_csv('data/forReview_RAoctB.csv')

# %%
# this is "record data" each row corresponds to an event:
### each event is a water sample from a location on particular day
#### for each event there are three samples, those three samples get split between three agar plates
##### each plate can have a total result of x_total = x1 + x2 +...+ x6
###### x1 ... x6 are subtotals that can be compared across dates and/or locations
# do the steps to get the descriptive statistics
# create output that can be used by : javaScript, django, bokeh
### at a granularity appropriate to establish an accurate assesment of the laboratory results
a_cols = list(a.columns)
def print_this_list(a):
    for x in a:
        print(x)
print(a_cols)
#check the columns
# Out:
# ['Date', 'Location', 'medium', 'Samples', 'Sampling_Notes', 'Water_temp', 'Plating_notes', 'Temp_incubation', 'P1_qty_sample', 'Image_24h_fluo_plate_one', 'P1_fluo_halo_colonies', 'P1_fluo_other', 'Plate_one_24h_image', 'P1_24h_big_blue', 'P1_24h_med_blue', 'P1_24h_green', 'P1_24h_turq', 'P1_24h_pink', 'P1_24h_other', 'Comments_p1_24h', 'Plate_one_48h_image', 'P1_48h_big_blue', 'P1_48h_med_blue', 'P1_48h_green', 'P1_48h_turq', 'P1_48h_pink', 'P1_48h_other', 'Comments_p1_48h', 'P2_qty_sample', 'Image_24h_fluo_plate_two', 'P2_fluo_halo_colonies', 'P2_fluo_other', 'Plate_two_24h_image', 'P2_24h_big_blue', 'P2_24h_med_blue', 'P2_24h_green', 'P2_24h_turq', 'P2_24h_pink', 'P2_24h_other', 'Comments_p2_24h', 'Plate_two_48h_image', 'P2_48h_big_blue', 'P2_48h_med_blue', 'P2_48h_green', 'P2_48h_turq', 'P2_48h_pink', 'P2_48h_other', 'Comments_p2_48h', 'P3_qty_sample', 'Image_24h_fluo_plate_three', 'p3_fluo_halo_colonies', 'p3_fluo_other', 'Plate_three_24h_image', 'P3_24h_big_blue', 'P3_24h_med_blue', 'P3_24h_green', 'P3_24h_turq', 'P3_24h_pink', 'P3_24h_other', 'Comments_p3_24h', 'Plate_three_48h_image', 'P3_48h_big_blue', 'P3_48h_med_blue', 'P3_48h_green', 'P3_48h_turq', 'P3_48h_pink', 'P3_48h_other', 'Comments_p3_48h', 'latitude', 'longitude', 'Location_Image']

# %%
# go in a terminal and check the date column
# it is in %y%.m%.d format
# for whatever reason the pd,datetime did not recoginze the data 17.06.12
# it flipped it to : 17.12.06 ---- which wont work
# so use some list index and str properties to make this right
b = a['Date'].copy()
new_dates = []
new_dic = {}
for x in b:
    year = '20'+str(x[6:])
    day = x[:2]
    month = x[3:5]
    new_d = year + '/' + str(month) + '/' + str(day)
    new_dates.append({x:new_d})
    new_dic.update({x:new_d})
new_dates[:10]

a['Date'] = a['Date'].map(new_dic)
a['Date'][:10]
# Out:
# 0    2017/06/12
# 1    2017/06/12
# 2    2017/06/12
# 3    2017/06/12
# 4    2017/06/12
# 5    2017/06/12
# 6    2017/06/19
# 7    2017/06/19
# 8    2017/06/19
# 9    2017/06/19
# Name: Date, dtype: object

# %%
# So there are alot of columns here
# index will be
# 'Date', 'Location', 'medium', 'Samples', 'Sampling_Notes', 'Water_temp', 'Plating_notes', 'Temp_incubation',
# I want that with each record for now

plate_one = ['P1_qty_sample',
             'Image_24h_fluo_plate_one',
             'P1_fluo_halo_colonies',
             'P1_fluo_other',
             'Plate_one_24h_image',
             'P1_24h_big_blue',
             'P1_24h_med_blue',
             'P1_24h_green',
             'P1_24h_turq',
             'P1_24h_pink',
             'P1_24h_other',
             'Comments_p1_24h',
             'Plate_one_48h_image',
             'P1_48h_big_blue',
             'P1_48h_med_blue',
             'P1_48h_green',
             'P1_48h_turq',
             'P1_48h_pink',
             'P1_48h_other',
             'Comments_p1_48h']

# %%
plate_two = ['P2_qty_sample',
             'Image_24h_fluo_plate_two',
             'P2_fluo_halo_colonies',
             'P2_fluo_other',
             'Plate_two_24h_image',
             'P2_24h_big_blue',
             'P2_24h_med_blue',
             'P2_24h_green',
             'P2_24h_turq',
             'P2_24h_pink',
             'P2_24h_other',
             'Comments_p2_24h',
             'Plate_two_48h_image',
             'P2_48h_big_blue',
             'P2_48h_med_blue',             
             'P2_48h_green',
             'P2_48h_turq',
             'P2_48h_pink',
             'P2_48h_other',
             'Comments_p2_48h']

# %%
plate_three = ['P3_qty_sample',
               'Image_24h_fluo_plate_three',
               'p3_fluo_halo_colonies',
               'p3_fluo_other',
               'Plate_three_24h_image',
               'P3_24h_big_blue',
               'P3_24h_med_blue',
               'P3_24h_green',
               'P3_24h_turq',
               'P3_24h_pink',
               'P3_24h_other',
               'Comments_p3_24h',
               'Plate_three_48h_image',
               'P3_48h_big_blue',
               'P3_48h_med_blue',
               'P3_48h_green',
               'P3_48h_turq',
               'P3_48h_pink',
               'P3_48h_other',
               'Comments_p3_48h']

# %%
map_it = ['Location','latitude', 'longitude']

# %%
index = ['Date',
         'Location',
         'medium',
         'Samples',
         'Sampling_Notes',
         'Water_temp',
         'Plating_notes',
         'Temp_incubation',]

# %%
# so the info repeats it self for each plate
# set up lists and variables to keep track of all that
# make sure that all the column names are accounted for
# we have yet to account for 'location_image'
def count_it(a):
    n = 0
    for x in a:
        a = len(x)
        n += a
    return n
groups = [index, map_it, plate_one, plate_two, plate_three]
print(count_it(groups), len(a_cols))
# the count works because the column 'location image' is not included
# Out:
# 71 71

# %%
loc_image = ['Date', 'Location', 'Location_Image']
groups.append(loc_image)
print(count_it(groups), len(a_cols))
#should be plus three
# Out:
# 74 71

# %%
# okay onwards
# break the results into time scale (beacuase i can)
# the info repeats it self
# this should get dwon to a series of lists
# if executed in right sequence as variables 
# will extract all possible combinations of the data provided
plate_one_24 = ['P1_qty_sample',
                'Plate_one_24h_image',
                'P1_24h_big_blue',
                'P1_24h_med_blue',
                'P1_24h_green',
                'P1_24h_turq',
                'P1_24h_pink',
                'P1_24h_other',
                'Comments_p1_24h',]
             
plate_one_48 = ['P1_qty_sample',
                'Plate_one_48h_image',
                'P1_48h_big_blue',
                'P1_48h_med_blue',
                'P1_48h_green',
                'P1_48h_turq',
                'P1_48h_pink',
                'P1_48h_other',
                'Comments_p1_48h']

# %%
# these can also be constructed using a list index method
plate_two_24 = ['P2_qty_sample',
                'Plate_two_24h_image',
                'P2_24h_big_blue',
                'P2_24h_med_blue',
                'P2_24h_green',
                'P2_24h_turq',
                'P2_24h_pink',
                'P2_24h_other',
                'Comments_p2_24h']

plate_two_48 = ['P2_qty_sample',
                'Plate_two_48h_image',
                'P2_48h_big_blue',
                'P2_48h_med_blue',             
                'P2_48h_green',
                'P2_48h_turq',
                'P2_48h_pink',
                'P2_48h_other',
                'Comments_p2_48h']

# %%
plate_three_24 = ['P3_qty_sample',
                  'Plate_three_24h_image',
                  'P3_24h_big_blue',
                  'P3_24h_med_blue',
                  'P3_24h_green',
                  'P3_24h_turq',
                  'P3_24h_pink',
                  'P3_24h_other',
                  'Comments_p3_24h',]
               
plate_three_48 = ['P3_qty_sample',
                  'Plate_three_48h_image',
                  'P3_48h_big_blue',
                  'P3_48h_med_blue',
                  'P3_48h_green',
                  'P3_48h_turq',
                  'P3_48h_pink',
                  'P3_48h_other',
                  'Comments_p3_48h']

# %%
plate_one_fluo = ['Image_24h_fluo_plate_one',
                  'P1_fluo_halo_colonies',
                  'P1_fluo_other']
plate_two_fluo = ['Image_24h_fluo_plate_two',
                  'P2_fluo_halo_colonies',
                  'P2_fluo_other']
plate_three_fluo = ['Image_24h_fluo_plate_three',
                    'p3_fluo_halo_colonies',
                    'p3_fluo_other']

# %%
# test the list indexes:
d = np.random.randint(9, size=8)
d
# Out:
# array([6, 1, 3, 8, 6, 6, 2, 6])

# %%
# or run this at each loop
np.random.choice(9)
# Out:
# 7

# %%
# this data can be seen as a whole (the sum of all the xis or seperated by incubation time)
plate_groups = [plate_one_24, plate_two_24, plate_three_24, plate_one_48, plate_two_48, plate_three_48]
plate_24 = plate_groups[:3]
plate_48 = plate_groups[3:]

# %%
# to check this i will grab a random number and sue it to
# index the lists created from the columns
# these will be used as lables later to call data out
# the out pt should be the same for all values x[i] where i = np.random.choice(9)

def check_indexes(a):
    n = 0
    i = np.random.choice(9)
    if n <= 4:        
        for x in a:
            print(x[i])
        print('loop')
        n += 1
        
check_indexes(plate_groups)
# okay this function can run forever and i get the same output from each group
# Out:
# Comments_p1_24h
# Comments_p2_24h
# Comments_p3_24h
# Comments_p1_48h
# Comments_p2_48h
# Comments_p3_48h
# loop

# %%
# group the dates by week number
# first get a sorted list by date
# any way you do it there is a transformation to happen
b = a['Date'].copy()
b = pd.to_datetime(b, format='%Y/%m/%d')
b = list(b)
b.sort()
b = list(set(b))
b.sort()
b
# the time stamp works here but it is a hassel in js
# the value will be kept but I will also asign a week no
# Out:
# [Timestamp('2017-06-12 00:00:00'),
#  Timestamp('2017-06-19 00:00:00'),
#  Timestamp('2017-06-26 00:00:00'),
#  Timestamp('2017-07-03 00:00:00'),
#  Timestamp('2017-07-10 00:00:00'),
#  Timestamp('2017-07-17 00:00:00'),
#  Timestamp('2017-07-24 00:00:00'),
#  Timestamp('2017-07-31 00:00:00')]

# %%
weeks_l = ['Week one', 'Week two', 'Week three', 'Week four', 'Week five', 'Week six', 'Week seven', 'Week eight']
weeks = dict(zip(weeks_l, b))
print(weeks, b)
# Out:
# {'Week one': Timestamp('2017-06-12 00:00:00'), 'Week two': Timestamp('2017-06-19 00:00:00'), 'Week three': Timestamp('2017-06-26 00:00:00'), 'Week four': Timestamp('2017-07-03 00:00:00'), 'Week five': Timestamp('2017-07-10 00:00:00'), 'Week six': Timestamp('2017-07-17 00:00:00'), 'Week seven': Timestamp('2017-07-24 00:00:00'), 'Week eight': Timestamp('2017-07-31 00:00:00')} [Timestamp('2017-06-12 00:00:00'), Timestamp('2017-06-19 00:00:00'), Timestamp('2017-06-26 00:00:00'), Timestamp('2017-07-03 00:00:00'), Timestamp('2017-07-10 00:00:00'), Timestamp('2017-07-17 00:00:00'), Timestamp('2017-07-24 00:00:00'), Timestamp('2017-07-31 00:00:00')]

# %%
# makesure the orignal df is up to speed
a['Date'] = pd.to_datetime(a['Date'],format='%Y/%m/%d' )

# %%
# create a list of place names
places = list(a['Location'].copy())
places = set(places)
place = list(places)
place
# Out:
# ['SVT',
#  'Nernier',
#  'MRD',
#  'Echandens',
#  'VNX',
#  'Hackuarium toilet',
#  'Hackuarium tap']

# %%
mediums = list(a['medium'].unique().copy())
mediums[0]
# Out:
# 'easy_gel'

# %%
place = ['Echandens',
         'SVT',
         'VNX',
         'MRD',
         'Nernier',
         'Hackuarium tap',
         'Hackuarium toilet']

# so now I should get a table of values
# corresponding to plate number and color for one date, and one location
# check to see what happens if use 1 of each list to slice the data-frame
c = a[(a.Location == place[4]) & (a.Date == weeks['Week one'])][[plate_one_24[2], plate_two_24[2], plate_three_24[2]]]

# %%
c
# Out:
#    P1_24h_big_blue  P2_24h_big_blue  P3_24h_big_blue
# 4              1.0              0.0              0.0

# %%
print(type(c))
# that output looks good
# create a list index for the plate counts
bugs = [2, 3, 4, 5, 6, 7]
# this is temporary and will be replaced with a list derived from the column names
# this information down here is good to know
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# there is already some pandas finctionality here
a_sum = c.sum()
b_sum = sum(a_sum)
c_sum = sum(c.sum())

print(c_sum)
print(a_sum)
# Out:
# 1.0
# P1_24h_big_blue    1.0
# P2_24h_big_blue    0.0
# P3_24h_big_blue    0.0
# dtype: float64

# %%
# this function produces a dict of results
# of the type {placeName:{weeknumber-i, color-i,total-i}...{weeknumber-n, color-n,total-n}}
# and gets the color names
# this could be used in most js charting libraries
#

n = {}
def results(w,x,y,z,v):
    #f = []
    #l = []
    m ={}
    o = []
    #g = []
    for key, value in w.items():
        for i in z:
            total = 0
            for plate in y:
                c = a[(a.Location == x) & (a.medium == v) & (a.Date == value)][plate[i]]
                total += c.sum()
                d = {'date': key, 'bug':str(plate[i]),'colonies':c.sum()}
                #print(d)
                #f.append(d)
            if str(plate[i][7:]) not in o:
                   o.append(str(plate[i][7:]))
            h = {'week':str(key), 'color':str(plate[i][7:]), 'total':total}
            #print(h)
            m.update({(x, str(key), str(plate[i][7:])):h})
    n.update({x:m})
                       
    return  n, o

#v, w, m, n= results(weeks,'VNX', plate_24, bugs)

# %%
# it runs long, check and see if there are pandas methods
# groupby comes to mind ---- to speed this up
for x in place:
    n, o = results(weeks,x, plate_24, bugs, mediums[0])

# %%
# so there are seven dicts with 48 dicts nested in each one
# the number makes sense
len(n), len(n['SVT'])
# Out:
# (7, 48)

# %%
# this is sufficient to mark a chart
# it is easier to remember and shorter to type
o
# Out:
# ['big_blue', 'med_blue', 'green', 'turq', 'pink', 'other']

# %%
# calling all the varaibles (inlcuding the new one)
# produces a result
# yay !!
print(str(place[1]), n[place[1]][(str(place[1]),weeks_l[1],'med_blue')])
# Out:
# SVT {'week': 'Week two', 'color': 'med_blue', 'total': 0.0}

# %%
# so use that to get weekly totals
def week_total_all(dic_t, place, week, bug):
    b = {}
    for beach in place:
        #print(beach)
        a = dic_t[beach]
        for date in week:
            total = 0
            for color in bug:
                #print(a[(beach, date, color)])
                total += a[(beach, date, color)]['total']
            #print(beach, date, str(total))
            b.update({(beach, date):total})
    return b
        
g = week_total_all(n, place, weeks_l, o)

# %%
# now I can start to get descriptive statistics and visualisations
# seperated by date, location, incubation time, plate number, color
# and have output that is almost ready to go for charting (js date and float parse on the browser)
# but is good for plotting in matplotlib
#g

# %%
import matplotlib
import matplotlib.pyplot as plt
def plot_weekly_totals(wks, plc, g):
    rows = len(wks)
    cols = len(plc) +1

    f, axar = plt.subplots(rows, cols, figsize=(18,14))
    f.subplots_adjust(hspace=0.6, wspace=0.3)

    for i, n in enumerate(wks):
        axar[i, 0].text(0, 0.5, n, fontsize=14)
        axar[i, 0].set_axis_off()
        for j, o in enumerate(plc):
            axar[i, j+1].bar(1, g[(o, n)],)
            axar[i, j+1].set_title(o)
            axar[i, j+1].set_ylim(0, g[(o, n)]+20)

    plt.show()

# %% [markdown]
# ## Grid plot of weekly totals for all colors and place names in data
# ## incubation time 24hours, medium: easy-gel

# %%
plot_weekly_totals(weeks_l, place, g)

# %%
# lets get total coliforms per week, per location
coliforms = o[:2]
coli_week = week_total_all(n, place, weeks_l, coliforms)

# %% [markdown]
# ## Grid plot of weekly total (med_blue + big_blue) for all colors and place names
# ## incubation time 24hours, medium: easy-gel

# %%
plot_weekly_totals(weeks_l, place, coli_week)

# %%
# so the output for the charts need to match the output from the data frame
# set up the conditions
# test one location at a time

# %%
# pull the data frame using the variables in the function
ee = a[(a.Location == 'SVT') & (a.medium == 'easy_gel')].copy()
ww = [plate_one_24, plate_two_24, plate_three_24]

# %%
ee.reset_index(inplace = True)
ee.set_index(index, inplace=True)

# %%
col_list = []
for plts in ww:
    col_list.append(plts[2])
    col_list.append(plts[3])

# %%
ff = ee[col_list].copy()

# %%
ff['total'] = ff[col_list].sum(axis=1)

# %%
ff['total'].values
# Out:
# array([ 0.,  0.,  0., 21.,  4.,  2.,  1.,  0.])

# %%
for x in weeks_l:
    hh = coli_week[('SVT', x)]
    print(hh)
# Out:
# 0.0
# 0.0
# 0.0
# 21.0
# 4.0
# 2.0
# 1.0
# 0.0

# %%
mediums[1]
# Out:
# 'micrology_card'

# %% [markdown]
# ## Grid plot of weekly totals for all colors and place names in data
# ## incubation time 24hours, medium: micrology-card

# %%
for x in place:
    micrology, o = results(weeks,x, plate_24, bugs, mediums[1])
microl = week_total_all(micrology, place, weeks_l, o)
plot_weekly_totals(weeks_l, place, microl)

# %% [markdown]
# ## Grid plot of weekly totals for (med_blue + big_blue) colors and all place names in data
# ## incubation time 24hours, medium: micrology-card

# %%
micro_week = week_total_all(micrology, place, weeks_l, coliforms)
plot_weekly_totals(weeks_l, place, micro_week)

# %%
mediums
# Out:
# ['easy_gel', 'micrology_card', 'unil_kitchen', 'levine']

# %% [markdown]
# ## Grid plot of weekly totals for all colors and place names in data
# ## incubation time 24hours, medium: unil-kitchen

# %%
for x in place:
    kitchen, o = results(weeks,x, plate_24, bugs, mediums[2])
kit = week_total_all(kitchen, place, weeks_l, o)
plot_weekly_totals(weeks_l, place, kit)

# %% [markdown]
# ## Grid plot of weekly totals for (med_blue + big_blue) colors and all place names in data
# ## incubation time 24hours, medium: unil-kitchen

# %%
kitchen_week = week_total_all(kitchen, place, weeks_l, coliforms)
plot_weekly_totals(weeks_l, place, kitchen_week )

# %% [markdown]
# ## Grid plot of weekly totals for all colors and place names in data
# ## incubation time 24hours, medium: levine

# %%
for x in place:
    levine, o = results(weeks,x, plate_24, bugs, mediums[3])
lev = week_total_all(levine, place, weeks_l, o)
plot_weekly_totals(weeks_l, place, lev)

# %% [markdown]
# ## Grid plot of weekly totals for (med_blue + big_blue) colors and all place names in data
# ## incubation time 24hours, medium: levine

# %%
levine_week = week_total_all(levine, place, weeks_l, coliforms)
plot_weekly_totals(weeks_l, place, levine_week )

# %%
plate_48 = [plate_one_48, plate_two_48, plate_three_48]

# %%
cc = [plate_48, plate_24]
big_blue, med_blue, green, turq, pink, other = [], [], [], [], [], []
for x in cc:
    for plate in x:        
        big_blue.append(plate[2])
        med_blue.append(plate[3])
        green.append(plate[4])
        turq.append(plate[5])
        pink.append(plate[6])
        other.append(plate[7])
#big_blue

# %%
#b is our list of dates
dates = b
all_colors = [big_blue, med_blue, green, turq, pink, other]

# %%
one_sample = [[big_blue[3],big_blue[0]],
              [med_blue[3], med_blue[0]],
              [green[3], green[0]],
              [turq[3], turq[0]],
              [pink[3], pink[0]],
              [other[3], other[0]]
             ] 

#one_sample

# %%
#all_colors

# %%
#ee = a[(a.Location == 'SVT') & (a.medium == 'easy_gel')].copy()
def averages(df, date, loc, medium, colony):
    for day in date:
        for place in loc:
            for med in medium:
                for color in colony:
                    a = df[(df.Date == day) & (df.Location == place) & (df.medium == med)][color].copy()                   
                    print(a.sum())
                    print(day,place, med, sum(a.sum()))
#averages(a, dates[:2], place[:2], mediums, all_colors)

# %%
#ee = a[(a.Location == 'SVT') & (a.medium == 'easy_gel')].copy()

def averages(df, date, places, medium, one_sample, two_sample, three_sample):
    for day in date:
        total = 0
        average = 0
        nine_5 = 0
        for place in places:
            if place in list(df[(df.date == day)]['Location']):
                record = df[(df.Date == day) & (df.Location == places) & (df.medium == medium)]
                if record['Samples'].item() == 1:
                    # then list 'one_sample" has the columns
                    for sample in one_sample:
                        a = record[sample]
                        total += sum(a.sum())
                        average += np.mean(a.sum())
                elif record['Samples'].item() == 2:
                    # then list 'two_sample' has the columns
                    for sample in two_sample:
                        a = record[sample]
                        total += sum(a.sum())
                        total += sum(a.sum())
                        average += np.mean(a.sum())
                elif record['Samples'].item() == 3:
                    # then list 'three_sample' has the columns
                    for sample in three_sample:
                        a = record[sample]
                        total += sum(a.sum())
                        average += np.mean(a.sum())
                
        
        
             
            
    
        for color in colony:
            a = df[(df.Date == day) & (df.Location == places) & (df.medium == medium)][color].copy()
            total += sum(a.sum())
            #print(a.sum())
            #print('count per plate')
            #print(day,places, medium, color[0])
            #print(a.sum())
            print('average below')
            total2 += np.mean(a.sum())
            print(day,places, medium, color[0][7:], np.mean(a.sum()))
        b = {(places, day):total2}
        print(b)
        print('loop')
            
        
#averages(a, dates, place[2], 'easy_gel', all_colors)

# %%
weeks_2 = dict(zip(b, weeks_l))

# %%
a.drop(12, inplace=True)

# %%
rows = len(dates)
cols = len(place) + 1
ind = np.arange(len(one_sample))
width = 1
colss = ['r', 'b', 'y', 'g', 'r', 'b']

#f, axar = plt.subplots(rows, cols, figsize=(18,14))
#f.subplots_adjust(hspace=0.6, wspace=0.3)
all_results = []
for n, beach in enumerate(place[:4]):
    chart_it = {beach:[]}
    the_results = []
    for i, date in enumerate(dates):        
        xx = a[(a.Date == date) & (a.Location == beach ) & (a.medium == 'easy_gel')]
        day_results = []
        for n, sample in enumerate(all_colors):
#             if sum(xx[sample].sum()) == 0:
#                 f_95 = 0
#             else:
            yy = list(xx[sample].sum())
            yr = []
            for d in yy:
                if d == 0:
                    yr.append(d)
                if d > 0:
                    yr.append(np.log(d))
#                 print(yy)
#                 yy = yy.apply(np.log)
#                 print(yy)
            yg = np.mean(yr)
            yh = np.std(yr)
            f_95 = yg+yh*1.649
            f_95 = np.exp(f_95).round(2)
            if xx[plate_one[0]].item() == 0.5:
                f_95 = f_95 * 200
            elif xx[plate_one[0]].item() == 1:
                f_95 = f_95 * 100
            elif xx[plate_one[0]].item() == 4:
                f_95 = f_95 * 25
            #print(beach,sample[0][7:], sum(yy))
            day_results.append(f_95)
            #w = day_results
            #name.append(beach)
            #vv = {beach:}
        #print(weeks_l[i], day_results)
        the_results.append({weeks_2[date]:day_results})
    chart_it[beach] = the_results
    all_results.append(chart_it)
    #print(chart_it)

# %%
a[(a.Date == date) & (a.Location == beach ) & (a.medium == 'easy_gel')][plate_one[0]]
# Out:
# 52    4.0
# Name: P1_qty_sample, dtype: float64

# %%
date, beach
# Out:
# (Timestamp('2017-07-31 00:00:00'), 'MRD')

# %%
a.iloc[12]
# Out:
# Date                          2017-06-26 00:00:00
# Location                                      SVT
# medium                                   easy_gel
# Samples                                         3
# Sampling_Notes                        No comments
# Water_temp                                     24
# Plating_notes                         No comments
# Temp_incubation                                37
# P1_qty_sample                                   4
# Image_24h_fluo_plate_one         SVT1-16_27_6.JPG
# P1_fluo_halo_colonies                           0
# P1_fluo_other                                   0
# Plate_one_24h_image             SVT1-16_27_26.JPG
# P1_24h_big_blue                                 0
# P1_24h_med_blue                                 0
# P1_24h_green                                    0
# P1_24h_turq                                     0
# P1_24h_pink                                     0
# P1_24h_other                                    0
# Comments_p1_24h                       No comments
# Plate_one_48h_image               svt1-18_4_0.JPG
# P1_48h_big_blue                                 0
# P1_48h_med_blue                                 2
# P1_48h_green                                    0
# P1_48h_turq                                     0
# P1_48h_pink                                     0
# P1_48h_other                                    0
# Comments_p1_48h                       No comments
# P2_qty_sample                                   4
# Image_24h_fluo_plate_two        SVT2-16_27_52.JPG
#                                      ...
# P2_48h_big_blue                                 0
# P2_48h_med_blue                                 2
# P2_48h_green                                    0
# P2_48h_turq                                     0
# P2_48h_pink                                     1
# P2_48h_other                                    0
# Comments_p2_48h                       No comments
# P3_qty_sample                                   4
# Image_24h_fluo_plate_three      SVT3-16_28_17.JPG
# p3_fluo_halo_colonies                           0
# p3_fluo_other                                   0
# Plate_three_24h_image           SVT3-16_28_27.JPG
# P3_24h_big_blue                                 0
# P3_24h_med_blue                                 0
# P3_24h_green                                    0
# P3_24h_turq                                     0
# P3_24h_pink                                     0
# P3_24h_other                                    0
# Comments_p3_24h                       No comments
# Plate_three_48h_image            svt3-18_4_24.JPG
# P3_48h_big_blue                                 0
# P3_48h_med_blue                                 0
# P3_48h_green                                    0
# P3_48h_turq                                     0
# P3_48h_pink                                     0
# P3_48h_other                                    0
# Comments_p3_48h                       No comments
# latitude                                  46.4382
# longitude                                 6.90511
# Location_Image                  1498473715032.jpg
# Name: 13, Length: 71, dtype: object

# %%
def plot_weekly_totals(x):
    rows = len(weeks_l)
    cols = len(x) +1
    ind = np.arange(6)
    width = 1
    colss = ['r', 'b', 'y', 'g', 'r', 'b']

    f, axar = plt.subplots(rows, cols, figsize=(18,14))
    f.subplots_adjust(hspace=0.6, wspace=0.3)

    for i, n in enumerate(x):
        if i == 0:
            for key, value in x[i].items():
                for j, k in enumerate(value):
                    axar[j, i].text(0, 0.5, weeks_l[j], fontsize=14)
                    axar[j, i].set_axis_off()
                    axar[j, i+1].bar(ind, k[weeks_l[j]], width, color=colss)
                    axar[j, i+1].set_title(key)
                    axar[j, i+1].set_ylim(0, max(k[weeks_l[j]]) + 10)
        else:
            for key, value in x[i].items():
                for j, k in enumerate(value):
#                     axar[j, i].text(0, 0.5, weeks_l[j], fontsize=14)
#                     axar[j, i].set_axis_off()
                    axar[j, i+1].bar(ind, k[weeks_l[j]], width, color=colss)
                    axar[j, i+1].set_title(key)
                    axar[j, i+1].set_ylim(0,max(k[weeks_l[j]]) + 10)
            
    plt.show()

# %%
plot_weekly_totals(all_results)

# %%
for i, x in enumerate(all_results[:1]):
    for key, value in all_results[i].items():
        for qu, oy in enumerate(value):
            print(value[qu])

# %%
all_results[1].key.value()
