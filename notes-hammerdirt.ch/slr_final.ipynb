# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle
import re
import os
from scipy.stats import norm
import scipy.stats

# %%
here = os.getcwd()
data = here + '/data'

# %%
# Get the treated data from project manager

# %%
a = pd.read_excel(data + '/slr_final.xlsx', sheet_name='SLR_Data', header=0, encoding='latin1')

# %%
# Get the existing location information
# this includes city, post code, river or lake etc...
# retrieved from current db for app

# %%
bch = pd.read_csv('/home/mw-shovel/Downloads/slr_beaches.csv', header=None)

# %%
bch[:1]
# Out:
#                             0         1        2     3     4      5   6
# 0  aarezufluss_bern_scheurerk  46.97101  7.45279  Bern  3004  river  \N

# %%
# compare the location names
# see if there were any added by the pm since the last upload

# %%
nme_p = list(a['BeachName'].unique())
nme_h = list(bch[0].unique())
dif = [x for x in nme_p + nme_h if x not in nme_p or x not in nme_p]
dif
# Out:
# []

# %%
# okay this is empty
# just to make it easier to understand what I did

# %%
# just to make sure:
def same_names(a,b):
    for c in a:
        if c not in b:
            print(c)
same_names(nme_h, nme_p)

# %%
# okay thats all good

# %%
# assign appropriate column names to the locations data table

# %%
bch.rename(columns={0:'Location', 1:'latitude', 2:'longitude', 3:'city', 4:'post', 5:'project'}, inplace=True)

# %%
# okay now reduce the slr_final data to what we need
# take a look at the columns
a_cs = a.columns

# %%
a_cs[:20]
# Out:
# Index(['BeachName', 'lat_y1', 'lon_x1', 'lat_y2', 'lon_x2', 'BeachLength_m',
#        'EventDate', 'G3', 'G4', 'G7', 'G8', 'G10', 'G13', 'G21', 'G22', 'G23',
#        'G24', 'G25', 'G26', 'G27'],
#       dtype='object')

# %%
new_cols =['BeachName','BeachLength_m','EventDate','G3','G4','G7','G8','G10','G13','G21','G22','G23',
           'G24','G25','G26','G27','G28','G30','G31','G32','G33','G34','G35','G37','G49','G50','G52',
           'G59','G65','G66','G67','G70','G71','G79','G80','G82','G83','G87','G89','G90','G91','G93',
           'G95','G96','G99','G100','G101','G124','G125','G126','G128','G131','G133','G134','G137','G138',
           'G142','G144','G145','G147','G151','G152','G153','G154','G155','G156','G158','G159','G160','G165',
           'G167','G171','G172','G175','G176','G177','G178','G179','G182','G188','G191','G194','G195','G198',
           'G199','G200','G203','G204','G208','G210','G211','G213','TOTAL','Area','DENSITY']

# %%
a_1 = a[new_cols].copy()

# %%
obs_v = a[['BeachName','Percent_WashedAshore']].copy()

# %%
# Need to identify all records where area = 0
# This will give a 'undefined' value for 'DENSITY'

# %%
a_1.fillna(0, inplace=True)

# %%
no_area = a_1.loc[a_1.Area == 0].copy()
no_area.to_csv('data/no_area.csv')

# %%
a_1.rename(columns={'BeachName':'location', 'BeachLength_m':'length', 'EventDate':'date'}, inplace=True)

# %%
# okay now we need to drop the records that have an area = 0
# notice I keep the original dataframe and make a new one

# %%
a_2 = a_1.loc[a_1.Area > 0].copy()

# %%
code_list = ['G3','G4','G7','G8','G10','G13','G21','G22','G23',
             'G24','G25','G26','G27','G28','G30','G31','G32','G33','G34','G35','G37','G49','G50','G52',
           'G59','G65','G66','G67','G70','G71','G79','G80','G82','G83','G87','G89','G90','G91','G93',
           'G95','G96','G99','G100','G101','G124','G125','G126','G128','G131','G133','G134','G137','G138',
           'G142','G144','G145','G147','G151','G152','G153','G154','G155','G156','G158','G159','G160','G165',
           'G167','G171','G172','G175','G176','G177','G178','G179','G182','G188','G191','G194','G195','G198',
           'G199','G200','G203','G204','G208','G210','G211','G213',]

# %%
def make_item_counts_pcm():
    d = []
    for a, b in a_1.iterrows():
        for code in code_list:
            if b[code] > 0:
                c = {'location':b['location'],'date':b['date'].strftime("%Y-%m-%d"), 'length':b['length'], 'quantity':b[code], 'density': b[code]/b['length'], 'code':code}
                d.append(c)
    return d
a_per_item_pcm = make_item_counts_pcm()

# %%
def make_item_counts_area():
    d = []
    for a, b in a_2.iterrows():
        for code in code_list:
            if b[code] > 0:
                c = {'location':b['location'],'date':b['date'].strftime("%Y-%m-%d"), 'area':b['Area'], 'quantity':b[code], 'density': b[code]/b['Area'], 'code':code}
                d.append(c)
    return d
a_per_item_area = make_item_counts_area()

# %%
# get the total of all the items found
# then get the daily density of all items per location per date

# %%
a_2['total']=a_2[code_list].sum(axis=1)
a_1['total']=a_1[code_list].sum(axis=1)
a_1 = a_1[a_1.total > 0].copy()

# %%
# the remote database has density as the column name for pcs/m
# will keep as is and name the total/area column as density2
# saves alot of work, and that can be changed later
a_1['density'] = a_1['total']/a_1['length']
a_2['density2'] = a_2['total']/a_2['Area']

# %%
slr_dens_date = a_1[['location', 'date', 'density', 'total']].copy()
slr_dens_date2 = a_2[['location', 'date', 'density2', 'total']].copy()

# %%
def change_name(df):
    df.rename(columns={'total':'quantity'})
change_name(slr_dens_date)

# %%
change_name(slr_dens_date2)

# %%
def get_sample_no(df):
    d = []
    for name in nme_p:
        a = df.loc[df.location == name]
        a = a.sort_values(by='date')
        a.reset_index(inplace=True)
        for i, row in a.iterrows():
            n=i+1
            c = {'location':row['location'], 'date':row['date'], 'sample':n, 'density2':row['density2'], 'quantity':row['total']}
            d.append(c)
    return d
slr_d_d2 = get_sample_no(slr_dens_date2)

# %%
slr_area_samps = pd.DataFrame(slr_d_d2)

# %%
slr_area_samps = slr_area_samps[['location', 'date', 'sample', 'density2', 'quantity']]

# %%
slr_area_samps['date'] = slr_area_samps['date'].dt.strftime("%Y-%m-%d")

# %%
slr_area_samps.set_index('date', inplace=True)

# %%
slr_area_samps['density2'] = slr_area_samps['density2'].round(3)
slr_area_samps['quantity'] = slr_area_samps['quantity'].astype(int)
slr_area_samps['sample'] = slr_area_samps['sample'].astype(int)

# %%
slr_area_samps.to_csv('data/slr_area.csv', encoding='latin1')

# %%
def get_sample_no(df):
    d = []
    for name in nme_p:
        a = df.loc[df.location == name]
        a = a.sort_values(by='date')
        a.reset_index(inplace=True)
        for i, row in a.iterrows():
            n=i+1
            c = {'location':row['location'], 'date':row['date'], 'sample':n, 'density':row['density'], 'quantity':row['total']}
            d.append(c)
    return d

# %%
slr_pcs_m = get_sample_no(slr_dens_date)

# %%
slr_p_m = pd.DataFrame(slr_pcs_m)
slr_p_m = slr_p_m[['location', 'date', 'sample', 'density', 'quantity']]
slr_p_m['date'] = slr_p_m['date'].dt.strftime("%Y-%m-%d")
# slr_p_m.set_index('date', inplace=True)
slr_p_m['density'] = slr_p_m['density'].round(4)
slr_p_m['quantity'] = slr_p_m['quantity'].astype(int)
slr_p_m['sample'] = slr_p_m['sample'].astype(int)

# %%
slr_p_m.set_index('location', inplace=True)

# %%
slr_p_m.to_csv('data/slr_pieces.csv', encoding='latin1')

# %%
# Out:
#                                             location  sample  density2  \
# date
# 2017-04-14                         Aare_bern_gerberm       1     0.642
# 2017-05-21                         Aare_bern_gerberm       2     0.111
# 2017-06-26                         Aare_bern_gerberm       3     0.789
# 2017-07-31                         Aare_bern_gerberm       4     0.339
# 2017-08-29                         Aare_bern_gerberm       5     0.486
# 2017-09-26                         Aare_bern_gerberm       6     0.460
# 2017-10-31                         Aare_bern_gerberm       7     0.270
# 2017-11-17                         Aare_bern_gerberm       8     0.147
# 2017-12-26                         Aare_bern_gerberm       9     0.213
# 2018-01-27                         Aare_bern_gerberm      10     0.693
# 2018-03-31                         Aare_bern_gerberm      11     0.282
# 2017-04-02                       aare_bern_scheurerk       1     0.100
# 2017-05-21                       aare_bern_scheurerk       2     0.000
# 2017-07-09                       aare_bern_scheurerk       3     1.600
# 2017-09-15                       aare_bern_scheurerk       4     0.012
# 2017-10-21                       aare_bern_scheurerk       5     0.006
# 2017-11-16                       aare_bern_scheurerk       6     0.017
# 2018-01-23                       aare_bern_scheurerk       7     0.000
# 2018-03-15                       aare_bern_scheurerk       8     0.008
# 2017-04-12                         Aare_Brugg_BuchiE       1     0.245
# 2017-05-08                         Aare_Brugg_BuchiE       2     0.440
# 2017-06-13                         Aare_Brugg_BuchiE       3     0.171
# 2017-07-20                         Aare_Brugg_BuchiE       4     0.250
# 2017-08-26                         Aare_Brugg_BuchiE       5     0.575
# 2017-09-25                         Aare_Brugg_BuchiE       6     0.122
# 2017-10-31                         Aare_Brugg_BuchiE       7     0.020
# 2017-11-27                         Aare_Brugg_BuchiE       8     0.015
# 2017-12-28                         Aare_Brugg_BuchiE       9     0.050
# 2018-02-04                         Aare_Brugg_BuchiE      10     0.050
# 2018-03-31                         Aare_Brugg_BuchiE      11     0.085
# ...                                              ...     ...       ...
# 2017-06-18  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ       3     5.040
# 2017-07-30  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ       4     1.840
# 2017-10-22  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ       5     2.040
# 2017-11-28  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ       6     1.240
# 2017-12-10  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ       7     1.027
# 2018-01-28  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ       8     2.833
# 2018-02-28  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ       9     1.200
# 2018-03-31  Zürichsee_Küsnachterhorn_Thirkell-WhiteJ      10     2.680
# 2017-04-17         zürichsee_wollishofen_langendorfm       1     0.796
# 2017-05-16         zürichsee_wollishofen_langendorfm       2     0.553
# 2017-06-18         zürichsee_wollishofen_langendorfm       3     0.970
# 2017-07-28         zürichsee_wollishofen_langendorfm       4     0.310
# 2017-08-14         zürichsee_wollishofen_langendorfm       5     1.715
# 2017-09-21         zürichsee_wollishofen_langendorfm       6     0.400
# 2017-10-16         zürichsee_wollishofen_langendorfm       7     0.635
# 2017-11-20         zürichsee_wollishofen_langendorfm       8     0.313
# 2017-12-12         zürichsee_wollishofen_langendorfm       9     0.173
# 2018-01-19         zürichsee_wollishofen_langendorfm      10     0.156
# 2018-02-13         zürichsee_wollishofen_langendorfm      11     0.044
# 2018-03-22         zürichsee_wollishofen_langendorfm      12     0.608
# 2017-04-19        Zürichsee-Feldeggstr-BänningerSand       1     1.740
# 2017-06-20        Zürichsee-Feldeggstr-BänningerSand       2     5.330
# 2017-07-20        Zürichsee-Feldeggstr-BänningerSand       3     2.850
# 2017-08-23        Zürichsee-Feldeggstr-BänningerSand       4     7.710
# 2017-09-27        Zürichsee-Feldeggstr-BänningerSand       5     5.410
# 2017-10-25        Zürichsee-Feldeggstr-BänningerSand       6     4.410
# 2017-11-29        Zürichsee-Feldeggstr-BänningerSand       7     1.120
# 2018-01-23        Zürichsee-Feldeggstr-BänningerSand       8     3.780
# 2018-02-24        Zürichsee-Feldeggstr-BänningerSand       9     3.160
# 2018-03-26        Zürichsee-Feldeggstr-BänningerSand      10     4.440
#
#             quantity
# date
# 2017-04-14       154
# 2017-05-21        20
# 2017-06-26        71
# 2017-07-31       112
# 2017-08-29       175
# 2017-09-26       207
# 2017-10-31       108
# 2017-11-17        66
# 2017-12-26        96
# 2018-01-27       187
# 2018-03-31       127
# 2017-04-02         2
# 2017-05-21         0
# 2017-07-09        80
# 2017-09-15        26
# 2017-10-21        13
# 2017-11-16        35
# 2018-01-23         0
# 2018-03-15        35
# 2017-04-12        49
# 2017-05-08        44
# 2017-06-13        24
# 2017-07-20        50
# 2017-08-26        69
# 2017-09-25        22
# 2017-10-31         4
# 2017-11-27         3
# 2017-12-28         8
# 2018-02-04         5
# 2018-03-31        17
# ...              ...
# 2017-06-18       126
# 2017-07-30        46
# 2017-10-22        51
# 2017-11-28        31
# 2017-12-10        19
# 2018-01-28        51
# 2018-02-28        30
# 2018-03-31        67
# 2017-04-17       398
# 2017-05-16       268
# 2017-06-18       353
# 2017-07-28       150
# 2017-08-14       211
# 2017-09-21       180
# 2017-10-16       254
# 2017-11-20       141
# 2017-12-12        78
# 2018-01-19        78
# 2018-02-13        42
# 2018-03-22       304
# 2017-04-19       174
# 2017-06-20       533
# 2017-07-20       285
# 2017-08-23       771
# 2017-09-27       541
# 2017-10-25       441
# 2017-11-29       112
# 2018-01-23       378
# 2018-02-24       316
# 2018-03-26       444
#
# [968 rows x 4 columns]
