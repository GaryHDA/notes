# %%
import pandas as pd
import numpy as np
import pickle
import os

# %%
here = os.getcwd()
os.listdir(here)
# Out:
# ['lakedata',
#  'functions.py',
#  'Integrate hydro, pop-Copy1.ipynb',
#  'data',
#  'Integrate hydro, pop.ipynb',
#  'BASEL_2018.ipynb',
#  '__pycache__',
#  '.ipynb_checkpoints']

# %%
lakes = here + '/lakedata'
data = here + '/data'

# %%
os.listdir(data)
# Out:
# ['combined_mc.p',
#  'zur_see_loc.p',
#  'beaches.csv',
#  'dfZur_see.p',
#  'm_a_one.p',
#  'city_list.txt',
#  'mcb_slr.p',
#  'z_see.p',
#  'dfLem_see.p',
#  'c_a_xfour.p',
#  'montreux.p',
#  'loc_pop.csv',
#  'codes.p',
#  'mon_hotel.xlsx',
#  'leman_twox.p',
#  'items.csv',
#  'c_a_four.p',
#  'mcbp.csv',
#  'water_bodies.json',
#  'l_two_p.p',
#  'water_bodies.p',
#  'c_a_xthree.p',
#  'leman_one.p',
#  'combined.csv',
#  'c_a_three.p',
#  'm_a_onex.p',
#  'zurich_see.p',
#  'water_bodies_all.p',
#  'post_list.txt',
#  'mcbp_beaches.csv',
#  'pop_area.csv',
#  'leman_two.p',
#  'mon_hotel.csv',
#  'c_a_one.p',
#  'z_see_p.p',
#  'c_a_xtwo.p',
#  'leman_onex.p',
#  'combined.p',
#  'l_one_p.p']

# %%
slr = pd.read_pickle(data + '/combined.p')

# %%
mcb = pd.read_pickle(data + '/combined_mc.p')

# %%
mcb.columns.difference(slr.columns)
# Out:
# Index([], dtype='object')

# %%
cols = mcb.columns

# %%
cols
# Out:
# Index(['code_id', 'date', 'pcs_m', 'length', 'location_id', 'quantity', 'city',
#        'latitude', 'longitude', 'post', 'water', 'pop', 'area', 'pop_dens',
#        'day'],
#       dtype='object')

# %%
vidy = mcb.loc[mcb.city == 'Montreux'].location_id.unique()[:]

# %%
for x in vidy:
    print(x)
# Out:
# Baye de Montreux - G
# Baye de Montreux - D
# Baye de Clarens
# Le Pierrier
# Pierrier sud

# %%
def get_lats(d, a):
    b = {}
    for name in a:
        c = d.loc[d.location_id == name, ][['latitude', 'longitude']]
        f = c[:1]
        e = {name: [f.latitude.item(), f.longitude.item()]}
        b.update(e)
    return b
get_lats(mcb, vidy)
# Out:
# {'Baye de Clarens': [46.439787, 6.888903],
#  'Baye de Montreux - D': [46.430962, 6.908672999999999],
#  'Baye de Montreux - G': [46.430834000000004, 6.908778],
#  'Le Pierrier': [46.439727000000005, 6.888967999999999],
#  'Pierrier sud': [46.4395601, 6.8910000999999985]}

# %%
# zurich_l_18 = a_c.copy()

# %%
# zurich_l[:3]

# %%
# zurich = zurich_l.append(zurich_l_18)

# %%
# len(zurich)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import MONDAY
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter

# %%
# zurich[:2]

# %%
# dates = zurich.index.values
# type(dates[1])

# %%
# zurich.reset_index(inplace=True)

# %%
# zurich.rename(columns={'index':'date', 0:'level'}, inplace=True)

# %%
# zurich.date = pd.to_datetime(zurich.date)
# zurich.level = zurich.level.astype(float)
# zurich = zurich.sort_values('date')
# zurich.to_pickle(data + '/zurich_see.p', )

# %%
# print(type(zurich.date[1]), type(zurich.level[1]))

# %%
zurich = pd.read_pickle(data + '/zurich_see.p')

# %%
min(zurich['date'])
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
zurich.plot(x='date', y='level')

# %%
here
# Out:
# '/home/mw-shovel/web/notes/basel'

# %%
data
# Out:
# '/home/mw-shovel/web/notes/basel/data'

# %%
os.listdir(data)
# Out:
# ['combined_mc.p',
#  'zur_see_loc.p',
#  'beaches.csv',
#  'dfZur_see.p',
#  'm_a_one.p',
#  'city_list.txt',
#  'mcb_slr.p',
#  'z_see.p',
#  'dfLem_see.p',
#  'c_a_xfour.p',
#  'montreux.p',
#  'loc_pop.csv',
#  'codes.p',
#  'mon_hotel.xlsx',
#  'leman_twox.p',
#  'items.csv',
#  'c_a_four.p',
#  'mcbp.csv',
#  'water_bodies.json',
#  'l_two_p.p',
#  'water_bodies.p',
#  'c_a_xthree.p',
#  'leman_one.p',
#  'combined.csv',
#  'c_a_three.p',
#  'm_a_onex.p',
#  'zurich_see.p',
#  'water_bodies_all.p',
#  'post_list.txt',
#  'mcbp_beaches.csv',
#  'pop_area.csv',
#  'leman_two.p',
#  'mon_hotel.csv',
#  'c_a_one.p',
#  'z_see_p.p',
#  'c_a_xtwo.p',
#  'leman_onex.p',
#  'combined.p',
#  'l_one_p.p']

# %%
# b_a = pd.read_csv(data + '/pop_area.csv', encoding = 'latin1')
# c_a = pd.read_csv(data + '/combined.csv', encoding = 'latin1')

# %%
# b_a[:5]

# %%
# c_a = pd.read_csv(data + '/combined.csv', encoding = 'latin1')
# c_a.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# c_a[:5]

# %%
# c_a.to_pickle(data + '/combined.p')

# %%
c_a = pd.read_pickle(data + '/combined.p')

# %%
# def update(df, df2):
#     b = list(df.location_id.unique())
#     for a in b:
#         print(a)
#         c = df2.loc[df2.location == a].Area.item()
#         #print(c)
#         df.loc[df.location_id == a, 'area'] = c
#     #print(c)
# update(c_a, b_a)

# %%
# len(c_a)

# %%
#c_a[4000:4050]

# %%
# c_a['pop_dens'] = c_a['pop']/c_a['area']

# %%
#c_a[7000:7050]

# %%
#c_a.location_id.unique()

# %%
#zdf = c_a.loc[(c_a.city == 'Zürich') & (c_a.water == 'lake')].copy()

# %%
#zdf[:4]

# %%
#z = zdf.groupby(['date','location_id', 'pop_dens'])[['density']].sum()

# %%
#z.index.get_level_values(1).unique()

# %%
# zurich_see = ['zuerichsee_zurich_kullg', 'Zürichsee-Feldeggstr-BänningerSand',
#               'zürichsee_wollishofen_langendorfm',
#               'zürichsee_Küsnachterhorn_Thirkell-WhiteJ',
#               'zuerichsee_maennedorf_vanderkaadene',
#               'zuerichsee_staefa_hennm',
#               'zuerichsee_richterswil_benkoem_2',
#               'zuerichsee_waedenswil_colomboc_1'
#              ]

# %%
# with open(data + '/zur_see_loc.p', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     pickle.dump(zurich_see, f, pickle.HIGHEST_PROTOCOL)

#zurich_see.to_pickle(data + '/zur_see_loc.p')

# %%
zurich_see = pd.read_pickle(data + '/zur_see_loc.p')
zurich_see
# Out:
# ['zuerichsee_zurich_kullg',
#  'Zürichsee-Feldeggstr-BänningerSand',
#  'zürichsee_wollishofen_langendorfm',
#  'zürichsee_Küsnachterhorn_Thirkell-WhiteJ',
#  'zuerichsee_maennedorf_vanderkaadene',
#  'zuerichsee_staefa_hennm',
#  'zuerichsee_richterswil_benkoem_2',
#  'zuerichsee_waedenswil_colomboc_1']

# %%
# c_a.to_csv(data + '/combined.csv', encoding='latin1')

# %%
# zdfx = c_a.loc[c_a.location_id.isin(zurich_see)].copy()

# %%
# zdfx.city.unique()

# %%
# zdfx[:10]

# %%
# z = zdfx.groupby(['date','location_id', 'pop_dens'])[['density']].sum()

# %%
# z[:10]

# %%
# z.reset_index(inplace=True)
# z.columns

# %%
#z.drop('index', axis=1, inplace=True)

# %%
#z.date.values

# %%
# z.date = pd.to_datetime(z.date)

# %%
# z_dates = zurich[zurich.date > '2017-03-15']

# %%
# fig, ax = plt.subplots(figsize=(12,7))
# x_one = z_dates.date.values
# y_one = z_dates.level.values
# x_two = z.date.values
# y_two = z.density.values
# y_three = z.pop_dens.values
# ax.plot(x_one, y_one, color='r')
# ax_one = ax.twinx()
# ax_one.scatter(x_two, y_two, s= y_three/10, color='b', alpha=0.5)
# plt.show()

# %%
c_a.columns
# Out:
# Index(['code_id', 'date', 'pcs_m', 'length', 'location_id', 'quantity', 'city',
#        'latitude', 'longitude', 'post', 'water', 'pop', 'area', 'pop_dens',
#        'day'],
#       dtype='object')

# %%
c_a_one = c_a.groupby(['date','location_id', 'pop_dens'])[['pcs_m']].sum().copy()
c_a_one.reset_index(inplace=True)

# %%
#c_a_one[:10]

# %%
#from matplotlib.dates import mdates
fig, ax_one = plt.subplots(figsize=(12,7))
#ax_one.set_yscale('log')
# x_one = z_dates.date.values
# y_one = z_dates.level.values
#x_two = z.date.values
x_two = c_a_one.date.values
x_two = pd.to_datetime(x_two)
y_two =c_a_one.pcs_m
y_three = c_a_one.pop_dens.values
ymin = np.exp(y_two.min()).round(2)
y25 = np.exp(np.percentile(y_two, 25)).round(2)
y50 = np.exp(np.percentile(y_two, 50)).round(2)
y75 = np.exp(np.percentile(y_two, 75)).round(2)
ymax = np.exp(y_two.max()).round(2)
# ax.plot(x_one, y_one, color='r')
# ax_one = ax.twinx()
monday = WeekdayLocator(MONDAY)
months = MonthLocator(interval=1, bymonthday=1)
#datemin = min()
#datemax = max(x_two)
#print(months)
monthsFmt = DateFormatter("%b '%y")
ax_one.scatter(x_two, y_two, s= np.sqrt(y_three), color='b', alpha=0.5)
ax_one.xaxis.set_major_locator(months)
ax_one.xaxis.set_major_formatter(monthsFmt)
ax_one.xaxis.set_minor_locator(monday)
#ax_one.set_yticklabels([str(ymin), str(y25), str(y50), str(y75), str(ymax)])
#ax_one.set_xlim(datemin, datemax)
#ax_one.autoscale_view()
#fig.autofmt_xdate()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-2e3de7b2a236> in <module>()
#       8 x_two = c_a_one.date.values
#       9 x_two = pd.to_datetime(x_two)
# ---> 10 y_two =c_a_one.density
#      11 y_three = c_a_one.pop_dens.values
#      12 ymin = np.exp(y_two.min()).round(2)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'density'

# %%
c_a_xtwo = c_a.groupby(['date','location_id', 'water', 'pop_dens'])[['density']].sum().copy()
c_a_xtwo.reset_index(inplace=True)

# %%
c_a_xthree = c_a_xtwo[c_a_xtwo.water == 'lake'].copy()
c_a_xfour = c_a_xtwo[c_a_xtwo.water == 'river'].copy()
c_a_xthree.reset_index(inplace=True)
c_a_xfour.reset_index(inplace=True)

# %%
#from matplotlib.dates import mdates
fig, ax_one = plt.subplots(figsize=(12,7))
x_one = c_a_xthree.date.values
#x_two = c_a_one.date.values
x_one = pd.to_datetime(x_one)
y_one = np.log(c_a_xthree.density)
r_one = c_a_xthree.pop_dens.values

x_two = c_a_xfour.date.values
x_two = pd.to_datetime(x_two)
y_two = np.log(c_a_xfour.density)
r_two = c_a_xfour.pop_dens.values

y_min = y_two.min()-0.5
y_max = y_one.max()+1
ymin = np.exp(y_one.min()).round(2)
y25 = np.exp(np.percentile(y_one, 25)).round(2)
y50 = np.exp(np.percentile(y_one, 50)).round(2)
y75 = np.exp(np.percentile(y_one, 75)).round(2)
ymax = np.exp(y_one.max()).round(2)
# ax.plot(x_one, y_one, color='r')
# ax_one = ax.twinx()
monday = WeekdayLocator(MONDAY)
months = MonthLocator(interval=1, bymonthday=1)
#datemin = min()
#datemax = max(x_two)
#print(months)
monthsFmt = DateFormatter("%b '%y")
ax_one.scatter(x_two, y_two, s= np.sqrt(r_two), color='b', label = 'River', alpha=0.5)
ax_one.scatter(x_one, y_one, s=np.sqrt(r_one), color='r', label='Lakes', alpha=0.5)
ax_one.xaxis.set_major_locator(months)
ax_one.xaxis.set_major_formatter(monthsFmt)
ax_one.xaxis.set_minor_locator(monday)
ax_one.set_ylim(y_min, y_max)
ax_one.set_yticklabels([str(0), str(ymin), str(y25), str(y50), str(y75), str(ymax)])
#ax_one.set_xlim(datemin, datemax)
#ax_one.autoscale_view()
#fig.autofmt_xdate()
plt.legend(loc='upper right')
plt.show()

# %%
os.listdir(data)
# Out:
# ['zur_see_loc.p',
#  'beaches.csv',
#  'city_list.txt',
#  'loc_pop.csv',
#  'codes.p',
#  'items.csv',
#  'mcbp.csv',
#  'combined.csv',
#  'zurich_see.p',
#  'post_list.txt',
#  'mcbp_beaches.csv',
#  'pop_area.csv',
#  'combined.p']

# %%
codes = pd.read_pickle(data+'/codes.p')

# %%
codes
# Out:
# [{'code': 'G213',
#   'description': 'Paraffin wax',
#   'material': 'Chemicals',
#   'source': 'Recreation'},
#  {'code': 'G137',
#   'description': 'Clothing, rags, hats etc.,,',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G138',
#   'description': 'Shoes and sandals',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G139',
#   'description': 'Backpacks',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G140',
#   'description': 'Bags (hessian or jute)',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G141',
#   'description': 'Carpet ',
#   'material': 'Cloth',
#   'source': 'Household'},
#  {'code': 'G142',
#   'description': 'Rope or string',
#   'material': 'Cloth',
#   'source': 'Household'},
#  {'code': 'G143',
#   'description': 'Sails, canvas',
#   'material': 'Cloth',
#   'source': 'Fishing'},
#  {'code': 'G144',
#   'description': 'Tampons',
#   'material': 'Cloth',
#   'source': 'Medical'},
#  {'code': 'G145',
#   'description': 'Other textiles',
#   'material': 'Cloth',
#   'source': 'Other'},
#  {'code': 'G200',
#   'description': 'Bottles',
#   'material': 'Glass',
#   'source': 'Food'},
#  {'code': 'G201',
#   'description': 'Jars',
#   'material': 'Glass',
#   'source': 'Food'},
#  {'code': 'G202',
#   'description': 'Light bulbs',
#   'material': 'Glass',
#   'source': 'Household'},
#  {'code': 'G203',
#   'description': 'Tableware',
#   'material': 'Glass',
#   'source': 'Household'},
#  {'code': 'G204',
#   'description': 'Construction material',
#   'material': 'Glass',
#   'source': 'Construction'},
#  {'code': 'G205',
#   'description': 'Fluorescent light tubes',
#   'material': 'Glass',
#   'source': 'Household'},
#  {'code': 'G206',
#   'description': 'Glass buoys',
#   'material': 'Glass',
#   'source': 'Fishing'},
#  {'code': 'G207',
#   'description': 'Octopus pots',
#   'material': 'Glass',
#   'source': 'Fishing'},
#  {'code': 'G208',
#   'description': 'Glass fragments',
#   'material': 'Glass',
#   'source': 'Other'},
#  {'code': 'G210',
#   'description': 'Other glass items',
#   'material': 'Glass',
#   'source': 'Other'},
#  {'code': 'G174',
#   'description': 'Aerosol spray cans',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G175',
#   'description': 'Beverage cans',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G176',
#   'description': 'Food cans',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G177',
#   'description': 'Foil wrappers',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G178',
#   'description': 'Bottle caps, lids',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G179',
#   'description': 'Disposable BBQs',
#   'material': 'Metal',
#   'source': 'Recreation'},
#  {'code': 'G180',
#   'description': 'Appliances',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G181',
#   'description': 'Tableware',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G182',
#   'description': 'Fishing related',
#   'material': 'Metal',
#   'source': 'Fishing'},
#  {'code': 'G184',
#   'description': 'Lobster pots',
#   'material': 'Metal',
#   'source': 'Fishing'},
#  {'code': 'G186',
#   'description': 'Industrial scrap',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G187',
#   'description': 'Drums',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G188',
#   'description': 'Other cans',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G189',
#   'description': 'Gas bottles',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G190',
#   'description': 'Paint cans',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G191',
#   'description': 'Wire, wire mesh',
#   'material': 'Metal',
#   'source': 'Construction'},
#  {'code': 'G193',
#   'description': 'car parts, batteries',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G194',
#   'description': 'Cables',
#   'material': 'Metal',
#   'source': 'Construction'},
#  {'code': 'G195',
#   'description': 'Batteries - household',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G198',
#   'description': 'Other metal pieces < 50cm',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G199',
#   'description': 'Other metal pieces > 50cm',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G103', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G104', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G105', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G106', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G107', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G108', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G109', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G110', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G111', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G112', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G113', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G114', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G115', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G116', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G117', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G118', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G119', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G120', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G121', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G122', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G123', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G135', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G136', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G146', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G149', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G168', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G169', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G170', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G173', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G183', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G185', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G192', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G196', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G197', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G2', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G20', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G209', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G212', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G38', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G39', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G48', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G51', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G55', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G6', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G61', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G74', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G75', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G78', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G81', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G94', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G147',
#   'description': 'Paper bags',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G148',
#   'description': 'Cardboard ',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G150',
#   'description': 'Milk cartons',
#   'material': 'Paper',
#   'source': 'Food'},
#  {'code': 'G151',
#   'description': 'Drink cartons other',
#   'material': 'Paper',
#   'source': 'Food'},
#  {'code': 'G152',
#   'description': 'Cigarette boxes',
#   'material': 'Paper',
#   'source': 'Tobaco'},
#  {'code': 'G153',
#   'description': 'Cups, food trays, wrappers',
#   'material': 'Paper',
#   'source': 'Food'},
#  {'code': 'G154',
#   'description': 'Newspapers, magazines',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G155',
#   'description': 'Tubes for fireworks',
#   'material': 'Paper',
#   'source': 'Recreation'},
#  {'code': 'G156',
#   'description': 'Paper fragments',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G157',
#   'description': 'None',
#   'material': 'Paper',
#   'source': 'None'},
#  {'code': 'G158',
#   'description': 'Other paper items',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G1',
#   'description': 'Six pack rings',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G10',
#   'description': 'Food containers',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G100',
#   'description': 'Medical containers',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G101',
#   'description': 'Dog feces bag',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G102',
#   'description': 'Flip-flops',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G11',
#   'description': 'Cosmetics for the beach',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G12',
#   'description': 'Other cosmetics',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G124',
#   'description': 'Other plastic or foam products',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G13',
#   'description': 'Other bottles',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G14',
#   'description': 'Engine oil bottles',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G15',
#   'description': 'Engine oil bottles > 50cm',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G16',
#   'description': 'Jerry cans',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G17',
#   'description': 'Injection gun cartridge',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G18',
#   'description': 'Crates/baskets',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G19',
#   'description': 'Car parts',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G21',
#   'description': 'Drink lids',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G22',
#   'description': 'Lids for chemicals',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G23',
#   'description': 'Lids unidentified',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G24',
#   'description': 'Plastic rings from lids',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G25',
#   'description': 'Tobacco wrappers',
#   'material': 'Plastic',
#   'source': 'Tobaco'},
#  {'code': 'G26',
#   'description': 'Cigarette lighters',
#   'material': 'Plastic',
#   'source': 'Tobaco'},
#  {'code': 'G27',
#   'description': 'Cigarette butts',
#   'material': 'Plastic',
#   'source': 'Tobaco'},
#  {'code': 'G28',
#   'description': 'Pens and lids',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G29',
#   'description': 'Combs and brushes',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G3',
#   'description': 'Shopping bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G30',
#   'description': 'Candy and snack wrappers',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G31',
#   'description': 'Lollypop sticks',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G32',
#   'description': 'Toys and fireworks',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G33',
#   'description': 'Cups and cup lids',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G34',
#   'description': 'Cutlery and trays',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G35',
#   'description': 'Straws and stirrers',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G36',
#   'description': 'Feed bags',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G37',
#   'description': 'Mesh bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G4',
#   'description': 'Freezer bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G40',
#   'description': 'Gloves household',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G41',
#   'description': 'Glove industrial',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G42',
#   'description': 'Crab lobster pots',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G43',
#   'description': 'Tags fishing or industry',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G44',
#   'description': 'Octopus pots',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G45',
#   'description': 'Mussel nets',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G46',
#   'description': 'Oyster trays',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G47',
#   'description': 'Sheeting from mussel culture',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G49',
#   'description': 'Rope > 1cm',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G5',
#   'description': 'Generic plastic bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G50',
#   'description': 'String < 1cm',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G52',
#   'description': 'Nets and pieces',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G53',
#   'description': 'Nets and pieces < 50cm',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G54',
#   'description': 'Nets and pieces > 50cm',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G56',
#   'description': 'Tangled nets',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G57',
#   'description': 'Fish boxes',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G58',
#   'description': 'Foam fish box',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G59',
#   'description': 'Fishing line',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G60',
#   'description': 'Light sticks',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G62',
#   'description': 'Floats for nets',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G63',
#   'description': 'Buoys',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G64',
#   'description': 'Fenders',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G65',
#   'description': 'Buckets',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G66',
#   'description': 'Strapping bands',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G67',
#   'description': 'Industrial sheeting',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G68',
#   'description': 'Fiberglass fragments',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G69',
#   'description': 'Helmets or hardhats',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G7',
#   'description': 'Drink bottles < 0.5l',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G70',
#   'description': 'Shotgun cartridges',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G71',
#   'description': 'Shoes sandals',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G72',
#   'description': 'Traffic cones',
#   'material': 'Plastic',
#   'source': 'Other'},
#  {'code': 'G73',
#   'description': 'Foam sponge',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G76',
#   'description': 'Plastic or polystyrene 2.5 > <',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G77',
#   'description': 'Plastic or polystyrene  > 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G79',
#   'description': 'Plastic pieces 2.5 > < 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G8',
#   'description': 'Drink bottles  > 0.5l',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G80',
#   'description': 'Plastic pieces > 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G82',
#   'description': 'Polystyrene pieces 2.5 > < 50c',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G83',
#   'description': 'Polystyrene pieces > 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G84',
#   'description': 'CD or CD box',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G85',
#   'description': 'Salt packaging',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G86',
#   'description': 'Fin trees',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G87',
#   'description': 'Masking tape',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G88',
#   'description': 'Telephone or pieces of',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G89',
#   'description': 'Plastic construction waste',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G9',
#   'description': 'Cleaner bottles',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G90',
#   'description': 'Plastic flower pots',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G91',
#   'description': 'Biomass holder',
#   'material': 'Plastic',
#   'source': 'Water Treament'},
#  {'code': 'G92',
#   'description': 'Bait containers',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G93',
#   'description': 'Cable ties ',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G95',
#   'description': 'Cotton swabs',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G96',
#   'description': 'Sanitary napkins, tampon appli',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G97',
#   'description': 'Toilet fresheners',
#   'material': 'Plastic',
#   'source': 'Water Treament'},
#  {'code': 'G98',
#   'description': 'Diapers - wipes',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G99',
#   'description': 'Syringes - needles',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G125',
#   'description': 'Balloons and balloon sticks',
#   'material': 'Rubber',
#   'source': 'Recreation'},
#  {'code': 'G126',
#   'description': 'Balls',
#   'material': 'Rubber',
#   'source': 'Recreation'},
#  {'code': 'G127',
#   'description': 'Rubber boots',
#   'material': 'Rubber',
#   'source': 'Industry'},
#  {'code': 'G128',
#   'description': 'Tires and belts',
#   'material': 'Rubber',
#   'source': 'Industry'},
#  {'code': 'G129',
#   'description': 'Inner tubes and rubber sheets',
#   'material': 'Rubber',
#   'source': 'Industry'},
#  {'code': 'G130',
#   'description': 'Wheels',
#   'material': 'Rubber',
#   'source': 'Household'},
#  {'code': 'G131',
#   'description': 'Rubber bands',
#   'material': 'Rubber',
#   'source': 'Household'},
#  {'code': 'G132',
#   'description': 'Bobbers (fishing)',
#   'material': 'Rubber',
#   'source': 'Recreation'},
#  {'code': 'G133',
#   'description': 'Condoms',
#   'material': 'Rubber',
#   'source': 'Medical'},
#  {'code': 'G134',
#   'description': 'Other rubber',
#   'material': 'Rubber',
#   'source': 'Other'},
#  {'code': 'G211',
#   'description': 'Other medical items',
#   'material': 'Unidentified',
#   'source': 'Medical'},
#  {'code': 'G159',
#   'description': 'Corks',
#   'material': 'Wood',
#   'source': 'Food'},
#  {'code': 'G160',
#   'description': 'Pallets',
#   'material': 'Wood',
#   'source': 'Industry'},
#  {'code': 'G161',
#   'description': 'Processed wood',
#   'material': 'Wood',
#   'source': 'Industry'},
#  {'code': 'G162',
#   'description': 'Crates',
#   'material': 'Wood',
#   'source': 'Industry'},
#  {'code': 'G163',
#   'description': 'Crab lobster pots',
#   'material': 'Wood',
#   'source': 'Fishing'},
#  {'code': 'G164',
#   'description': 'Fish boxes',
#   'material': 'Wood',
#   'source': 'Fishing'},
#  {'code': 'G165',
#   'description': 'Ice cream sticks, chopsticks',
#   'material': 'Wood',
#   'source': 'Food'},
#  {'code': 'G166',
#   'description': 'Paint brushes',
#   'material': 'Wood',
#   'source': 'Construction'},
#  {'code': 'G167',
#   'description': 'Matches or fireworks',
#   'material': 'Wood',
#   'source': 'Recreation'},
#  {'code': 'G171',
#   'description': 'Other wood < 50cm',
#   'material': 'Wood',
#   'source': 'Other'},
#  {'code': 'G172',
#   'description': 'Other wood > 50cm',
#   'material': 'Wood',
#   'source': 'Other'}]

# %%
a = 'Strapping bands'
b = 'Industrial sheeting'
c = 'Plastic construction waste'
d = 'Cable ties '
e = 'Fragmented'
f = 'description'
g = 'source'
change = [a, b, c, d]

# %%
def update_codes():
    for a in codes:
        #print(a['description'])
        if a['description'] in change:
            print(True)
            a[g] = e
update_codes()
# Out:
# True
# True
# True
# True

# %%
def print_codes(source):
    print(source)
    for a in codes:
        #print(a['source'])
        if a['source'] == source:
            #print('true')
            print(a[f])
print_codes(e)
# Out:
# Fragmented
# Other plastic or foam products
# Strapping bands
# Industrial sheeting
# Plastic or polystyrene 2.5 > <
# Plastic or polystyrene  > 50cm
# Plastic pieces 2.5 > < 50cm
# Plastic pieces > 50cm
# Polystyrene pieces 2.5 > < 50c
# Polystyrene pieces > 50cm
# Plastic construction waste
# Cable ties

# %%
codes
# Out:
# [{'code': 'G213',
#   'description': 'Paraffin wax',
#   'material': 'Chemicals',
#   'source': 'Recreation'},
#  {'code': 'G137',
#   'description': 'Clothing, rags, hats etc.,,',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G138',
#   'description': 'Shoes and sandals',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G139',
#   'description': 'Backpacks',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G140',
#   'description': 'Bags (hessian or jute)',
#   'material': 'Cloth',
#   'source': 'Personal effects'},
#  {'code': 'G141',
#   'description': 'Carpet ',
#   'material': 'Cloth',
#   'source': 'Household'},
#  {'code': 'G142',
#   'description': 'Rope or string',
#   'material': 'Cloth',
#   'source': 'Household'},
#  {'code': 'G143',
#   'description': 'Sails, canvas',
#   'material': 'Cloth',
#   'source': 'Fishing'},
#  {'code': 'G144',
#   'description': 'Tampons',
#   'material': 'Cloth',
#   'source': 'Medical'},
#  {'code': 'G145',
#   'description': 'Other textiles',
#   'material': 'Cloth',
#   'source': 'Other'},
#  {'code': 'G200',
#   'description': 'Bottles',
#   'material': 'Glass',
#   'source': 'Food'},
#  {'code': 'G201',
#   'description': 'Jars',
#   'material': 'Glass',
#   'source': 'Food'},
#  {'code': 'G202',
#   'description': 'Light bulbs',
#   'material': 'Glass',
#   'source': 'Household'},
#  {'code': 'G203',
#   'description': 'Tableware',
#   'material': 'Glass',
#   'source': 'Household'},
#  {'code': 'G204',
#   'description': 'Construction material',
#   'material': 'Glass',
#   'source': 'Construction'},
#  {'code': 'G205',
#   'description': 'Fluorescent light tubes',
#   'material': 'Glass',
#   'source': 'Household'},
#  {'code': 'G206',
#   'description': 'Glass buoys',
#   'material': 'Glass',
#   'source': 'Fishing'},
#  {'code': 'G207',
#   'description': 'Octopus pots',
#   'material': 'Glass',
#   'source': 'Fishing'},
#  {'code': 'G208',
#   'description': 'Glass fragments',
#   'material': 'Glass',
#   'source': 'Other'},
#  {'code': 'G210',
#   'description': 'Other glass items',
#   'material': 'Glass',
#   'source': 'Other'},
#  {'code': 'G174',
#   'description': 'Aerosol spray cans',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G175',
#   'description': 'Beverage cans',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G176',
#   'description': 'Food cans',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G177',
#   'description': 'Foil wrappers',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G178',
#   'description': 'Bottle caps, lids',
#   'material': 'Metal',
#   'source': 'Food'},
#  {'code': 'G179',
#   'description': 'Disposable BBQs',
#   'material': 'Metal',
#   'source': 'Recreation'},
#  {'code': 'G180',
#   'description': 'Appliances',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G181',
#   'description': 'Tableware',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G182',
#   'description': 'Fishing related',
#   'material': 'Metal',
#   'source': 'Fishing'},
#  {'code': 'G184',
#   'description': 'Lobster pots',
#   'material': 'Metal',
#   'source': 'Fishing'},
#  {'code': 'G186',
#   'description': 'Industrial scrap',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G187',
#   'description': 'Drums',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G188',
#   'description': 'Other cans',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G189',
#   'description': 'Gas bottles',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G190',
#   'description': 'Paint cans',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G191',
#   'description': 'Wire, wire mesh',
#   'material': 'Metal',
#   'source': 'Construction'},
#  {'code': 'G193',
#   'description': 'car parts, batteries',
#   'material': 'Metal',
#   'source': 'Industry'},
#  {'code': 'G194',
#   'description': 'Cables',
#   'material': 'Metal',
#   'source': 'Construction'},
#  {'code': 'G195',
#   'description': 'Batteries - household',
#   'material': 'Metal',
#   'source': 'Household'},
#  {'code': 'G198',
#   'description': 'Other metal pieces < 50cm',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G199',
#   'description': 'Other metal pieces > 50cm',
#   'material': 'Metal',
#   'source': 'Other'},
#  {'code': 'G103', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G104', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G105', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G106', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G107', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G108', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G109', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G110', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G111', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G112', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G113', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G114', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G115', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G116', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G117', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G118', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G119', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G120', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G121', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G122', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G123', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G135', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G136', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G146', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G149', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G168', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G169', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G170', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G173', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G183', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G185', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G192', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G196', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G197', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G2', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G20', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G209', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G212', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G38', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G39', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G48', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G51', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G55', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G6', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G61', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G74', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G75', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G78', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G81', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G94', 'description': 'None', 'material': 'None', 'source': 'None'},
#  {'code': 'G147',
#   'description': 'Paper bags',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G148',
#   'description': 'Cardboard ',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G150',
#   'description': 'Milk cartons',
#   'material': 'Paper',
#   'source': 'Food'},
#  {'code': 'G151',
#   'description': 'Drink cartons other',
#   'material': 'Paper',
#   'source': 'Food'},
#  {'code': 'G152',
#   'description': 'Cigarette boxes',
#   'material': 'Paper',
#   'source': 'Tobaco'},
#  {'code': 'G153',
#   'description': 'Cups, food trays, wrappers',
#   'material': 'Paper',
#   'source': 'Food'},
#  {'code': 'G154',
#   'description': 'Newspapers, magazines',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G155',
#   'description': 'Tubes for fireworks',
#   'material': 'Paper',
#   'source': 'Recreation'},
#  {'code': 'G156',
#   'description': 'Paper fragments',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G157',
#   'description': 'None',
#   'material': 'Paper',
#   'source': 'None'},
#  {'code': 'G158',
#   'description': 'Other paper items',
#   'material': 'Paper',
#   'source': 'Other'},
#  {'code': 'G1',
#   'description': 'Six pack rings',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G10',
#   'description': 'Food containers',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G100',
#   'description': 'Medical containers',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G101',
#   'description': 'Dog feces bag',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G102',
#   'description': 'Flip-flops',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G11',
#   'description': 'Cosmetics for the beach',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G12',
#   'description': 'Other cosmetics',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G124',
#   'description': 'Other plastic or foam products',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G13',
#   'description': 'Other bottles',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G14',
#   'description': 'Engine oil bottles',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G15',
#   'description': 'Engine oil bottles > 50cm',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G16',
#   'description': 'Jerry cans',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G17',
#   'description': 'Injection gun cartridge',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G18',
#   'description': 'Crates/baskets',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G19',
#   'description': 'Car parts',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G21',
#   'description': 'Drink lids',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G22',
#   'description': 'Lids for chemicals',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G23',
#   'description': 'Lids unidentified',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G24',
#   'description': 'Plastic rings from lids',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G25',
#   'description': 'Tobacco wrappers',
#   'material': 'Plastic',
#   'source': 'Tobaco'},
#  {'code': 'G26',
#   'description': 'Cigarette lighters',
#   'material': 'Plastic',
#   'source': 'Tobaco'},
#  {'code': 'G27',
#   'description': 'Cigarette butts',
#   'material': 'Plastic',
#   'source': 'Tobaco'},
#  {'code': 'G28',
#   'description': 'Pens and lids',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G29',
#   'description': 'Combs and brushes',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G3',
#   'description': 'Shopping bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G30',
#   'description': 'Candy and snack wrappers',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G31',
#   'description': 'Lollypop sticks',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G32',
#   'description': 'Toys and fireworks',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G33',
#   'description': 'Cups and cup lids',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G34',
#   'description': 'Cutlery and trays',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G35',
#   'description': 'Straws and stirrers',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G36',
#   'description': 'Feed bags',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G37',
#   'description': 'Mesh bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G4',
#   'description': 'Freezer bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G40',
#   'description': 'Gloves household',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G41',
#   'description': 'Glove industrial',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G42',
#   'description': 'Crab lobster pots',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G43',
#   'description': 'Tags fishing or industry',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G44',
#   'description': 'Octopus pots',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G45',
#   'description': 'Mussel nets',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G46',
#   'description': 'Oyster trays',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G47',
#   'description': 'Sheeting from mussel culture',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G49',
#   'description': 'Rope > 1cm',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G5',
#   'description': 'Generic plastic bags',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G50',
#   'description': 'String < 1cm',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G52',
#   'description': 'Nets and pieces',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G53',
#   'description': 'Nets and pieces < 50cm',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G54',
#   'description': 'Nets and pieces > 50cm',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G56',
#   'description': 'Tangled nets',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G57',
#   'description': 'Fish boxes',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G58',
#   'description': 'Foam fish box',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G59',
#   'description': 'Fishing line',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G60',
#   'description': 'Light sticks',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G62',
#   'description': 'Floats for nets',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G63',
#   'description': 'Buoys',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G64',
#   'description': 'Fenders',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G65',
#   'description': 'Buckets',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G66',
#   'description': 'Strapping bands',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G67',
#   'description': 'Industrial sheeting',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G68',
#   'description': 'Fiberglass fragments',
#   'material': 'Plastic',
#   'source': 'Fishing'},
#  {'code': 'G69',
#   'description': 'Helmets or hardhats',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G7',
#   'description': 'Drink bottles < 0.5l',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G70',
#   'description': 'Shotgun cartridges',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G71',
#   'description': 'Shoes sandals',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G72',
#   'description': 'Traffic cones',
#   'material': 'Plastic',
#   'source': 'Other'},
#  {'code': 'G73',
#   'description': 'Foam sponge',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G76',
#   'description': 'Plastic or polystyrene 2.5 > <',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G77',
#   'description': 'Plastic or polystyrene  > 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G79',
#   'description': 'Plastic pieces 2.5 > < 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G8',
#   'description': 'Drink bottles  > 0.5l',
#   'material': 'Plastic',
#   'source': 'Food'},
#  {'code': 'G80',
#   'description': 'Plastic pieces > 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G82',
#   'description': 'Polystyrene pieces 2.5 > < 50c',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G83',
#   'description': 'Polystyrene pieces > 50cm',
#   'material': 'Plastic',
#   'source': 'Fragmented'},
#  {'code': 'G84',
#   'description': 'CD or CD box',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G85',
#   'description': 'Salt packaging',
#   'material': 'Plastic',
#   'source': 'Industry'},
#  {'code': 'G86',
#   'description': 'Fin trees',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G87',
#   'description': 'Masking tape',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G88',
#   'description': 'Telephone or pieces of',
#   'material': 'Plastic',
#   'source': 'Personal effects'},
#  {'code': 'G89',
#   'description': 'Plastic construction waste',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G9',
#   'description': 'Cleaner bottles',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G90',
#   'description': 'Plastic flower pots',
#   'material': 'Plastic',
#   'source': 'Household'},
#  {'code': 'G91',
#   'description': 'Biomass holder',
#   'material': 'Plastic',
#   'source': 'Water Treament'},
#  {'code': 'G92',
#   'description': 'Bait containers',
#   'material': 'Plastic',
#   'source': 'Recreation'},
#  {'code': 'G93',
#   'description': 'Cable ties ',
#   'material': 'Plastic',
#   'source': 'Construction'},
#  {'code': 'G95',
#   'description': 'Cotton swabs',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G96',
#   'description': 'Sanitary napkins, tampon appli',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G97',
#   'description': 'Toilet fresheners',
#   'material': 'Plastic',
#   'source': 'Water Treament'},
#  {'code': 'G98',
#   'description': 'Diapers - wipes',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G99',
#   'description': 'Syringes - needles',
#   'material': 'Plastic',
#   'source': 'Medical'},
#  {'code': 'G125',
#   'description': 'Balloons and balloon sticks',
#   'material': 'Rubber',
#   'source': 'Recreation'},
#  {'code': 'G126',
#   'description': 'Balls',
#   'material': 'Rubber',
#   'source': 'Recreation'},
#  {'code': 'G127',
#   'description': 'Rubber boots',
#   'material': 'Rubber',
#   'source': 'Industry'},
#  {'code': 'G128',
#   'description': 'Tires and belts',
#   'material': 'Rubber',
#   'source': 'Industry'},
#  {'code': 'G129',
#   'description': 'Inner tubes and rubber sheets',
#   'material': 'Rubber',
#   'source': 'Industry'},
#  {'code': 'G130',
#   'description': 'Wheels',
#   'material': 'Rubber',
#   'source': 'Household'},
#  {'code': 'G131',
#   'description': 'Rubber bands',
#   'material': 'Rubber',
#   'source': 'Household'},
#  {'code': 'G132',
#   'description': 'Bobbers (fishing)',
#   'material': 'Rubber',
#   'source': 'Recreation'},
#  {'code': 'G133',
#   'description': 'Condoms',
#   'material': 'Rubber',
#   'source': 'Medical'},
#  {'code': 'G134',
#   'description': 'Other rubber',
#   'material': 'Rubber',
#   'source': 'Other'},
#  {'code': 'G211',
#   'description': 'Other medical items',
#   'material': 'Unidentified',
#   'source': 'Medical'},
#  {'code': 'G159',
#   'description': 'Corks',
#   'material': 'Wood',
#   'source': 'Food'},
#  {'code': 'G160',
#   'description': 'Pallets',
#   'material': 'Wood',
#   'source': 'Industry'},
#  {'code': 'G161',
#   'description': 'Processed wood',
#   'material': 'Wood',
#   'source': 'Industry'},
#  {'code': 'G162',
#   'description': 'Crates',
#   'material': 'Wood',
#   'source': 'Industry'},
#  {'code': 'G163',
#   'description': 'Crab lobster pots',
#   'material': 'Wood',
#   'source': 'Fishing'},
#  {'code': 'G164',
#   'description': 'Fish boxes',
#   'material': 'Wood',
#   'source': 'Fishing'},
#  {'code': 'G165',
#   'description': 'Ice cream sticks, chopsticks',
#   'material': 'Wood',
#   'source': 'Food'},
#  {'code': 'G166',
#   'description': 'Paint brushes',
#   'material': 'Wood',
#   'source': 'Construction'},
#  {'code': 'G167',
#   'description': 'Matches or fireworks',
#   'material': 'Wood',
#   'source': 'Recreation'},
#  {'code': 'G171',
#   'description': 'Other wood < 50cm',
#   'material': 'Wood',
#   'source': 'Other'},
#  {'code': 'G172',
#   'description': 'Other wood > 50cm',
#   'material': 'Wood',
#   'source': 'Other'}]

# %%
#codes.to_pickle(data + '/codes.p')
with open(data + '/codes.p', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(codes, f, pickle.HIGHEST_PROTOCOL)

# %%
z_pivot_q = dfZ.pivot_table(['quantity'], index=['date', 'city', 'post', 'water', 'location_id'], columns=['code_id'], fill_value=0)
