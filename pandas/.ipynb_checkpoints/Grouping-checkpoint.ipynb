# %% [markdown]
# ## Grouping operataions

# %% [markdown]
# #### References
# 1. Python for data analysis
# 2. Think stats: exploratory data analysis
# 3. https://pandas.pydata,org
#
# #### Purpose
# 1. Work in the abstract (its good for the brain)
# 2. Keep up to date with changes in the library
# 3. Explore new ways of doing common tasks --- get better

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle

# %%
# get some data
# use the trash data
# incase you forgot the ~ tilda replaces '/home/mw-shovel' or whate ever your home dir is

dfA = pd.read_csv('~/web/notes/basel/data/combined.csv', encoding='latin1')

# %%
# make sure the data is good
dfA[:5]
# Out:
#   code_id        date  density   id  length         location_id  quantity  \
# 0     G21  2017-04-02    0.071  1.0    28.0  Aare_Bern_CaveltiN       2.0
# 1     G27  2017-04-02    0.429  2.0    28.0  Aare_Bern_CaveltiN      12.0
# 2     G30  2017-04-02    0.036  3.0    28.0  Aare_Bern_CaveltiN       1.0
# 3     G33  2017-04-02    0.036  4.0    28.0  Aare_Bern_CaveltiN       1.0
# 4     G66  2017-04-02    0.036  5.0    28.0  Aare_Bern_CaveltiN       1.0
#
#             city   latitude  longitude  post  water      pop
# 0  Muri bei Bern  46.923579   7.473319  3074  river  13187.0
# 1  Muri bei Bern  46.923579   7.473319  3074  river  13187.0
# 2  Muri bei Bern  46.923579   7.473319  3074  river  13187.0
# 3  Muri bei Bern  46.923579   7.473319  3074  river  13187.0
# 4  Muri bei Bern  46.923579   7.473319  3074  river  13187.0

# %%
# do not delete any columns here
# just grab what is needed as it is needed
# will change a column name

dfA.rename(columns={'density':'pcs_per_m'}, inplace=True)

# %%
# get the average density of each code_id
codes = dfA.pcs_per_m.groupby(dfA.code_id)

# %%
codes.mean()[:20]
# Out:
# code_id
# G10     0.044044
# G100    0.054795
# G101    0.039837
# G124    0.112172
# G125    0.076084
# G126    0.029282
# G128    0.039750
# G13     0.043375
# G131    0.046959
# G133    0.026857
# G134    0.054524
# G137    0.035386
# G138    0.037667
# G142    0.063908
# G144    0.037548
# G145    0.085759
# G147    0.033107
# G151    0.059221
# G152    0.041752
# G153    0.040600
# Name: pcs_per_m, dtype: float64

# %%
# this can be done with an array of values
# try with postal code
codes = dfA.pcs_per_m.groupby([dfA.code_id, dfA.post])
codes.mean()[:2]
# Out:
# code_id  post
# G10      1007    0.0370
#          1196    0.0835
# Name: pcs_per_m, dtype: float64

# %%
# or do this rivers vs lakes
codes = dfA.pcs_per_m.groupby([dfA.code_id, dfA.water])
codes.mean()[:5]
# Out:
# code_id  water
# G10      lake     0.055737
#          river    0.035500
# G100     lake     0.068510
#          river    0.032938
# G101     lake     0.047083
# Name: pcs_per_m, dtype: float64

# %%
plt.figure(figsize=(12,5));
codes.mean()[:20].plot.bar()
plt.show()

# %%
# group by elements can be stored in a dictionary
# the dict key is a tuple given by the group by keys
pieces = dict(list(dfA.pcs_per_m.groupby([dfA.post, dfA.code_id])))
pieces[(1007, 'G27')]
# Out:
# 3941    2.926
# 3972    1.444
# 4001    1.852
# 4030    3.667
# 4051    2.630
# 4076    1.185
# 4098    0.889
# 4116    0.444
# 4132    0.185
# 4150    0.481
# 4176    0.630
# Name: pcs_per_m, dtype: float64

# %%
# one of these will give a df, the other will give a series

pcs_1 = dfA.pcs_per_m.groupby([dfA.post, dfA.code_id])
pcs_2 = dfA.groupby([dfA.post, dfA.code_id])[['pcs_per_m']]

# %%
print(type(pcs_2), type(pcs_1))
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'> <class 'pandas.core.groupby.SeriesGroupBy'>

# %%
pcs_2.mean()[:10]#< --- this is a dataframe
# Out:
#               pcs_per_m
# post code_id
# 1007 G10        0.03700
#      G100       0.10175
#      G101       0.05550
#      G125       0.14800
#      G126       0.03700
#      G131       0.04625
#      G133       0.03700
#      G134       0.03700
#      G142       0.07400
#      G144       0.03700

# %%
pcs_1.mean()[:10]#<----- this is a series
# Out:
# post  code_id
# 1007  G10        0.03700
#       G100       0.10175
#       G101       0.05550
#       G125       0.14800
#       G126       0.03700
#       G131       0.04625
#       G133       0.03700
#       G134       0.03700
#       G142       0.07400
#       G144       0.03700
# Name: pcs_per_m, dtype: float64

# %%
t = pcs_2.mean()

# %%
t.loc[1007][:8]#<---- this is a df so the indexer can be used
# Out:
#          pcs_per_m
# code_id
# G10        0.03700
# G100       0.10175
# G101       0.05550
# G125       0.14800
# G126       0.03700
# G131       0.04625
# G133       0.03700
# G134       0.03700

# %%
# load some values
codes = pickle.load(open('/home/mw-shovel/web/notes/basel/data/codes.p', 'rb'))
codes[1]
# Out:
# {'code': 'G137',
#  'description': 'Clothing, rags, hats etc.,,',
#  'material': 'Cloth',
#  'source': 'Personal effects'}

# %%
# create a dict that can be used to groupby
def code_source(x):
    a = {}
    for i in x:
        b = {i['code']:i['source']}
        a.update(b)
    return a
sources = code_source(codes)

# %%
def code_desc(x):
    a = {}
    c = {}
    for i in x:
        b = {i['code']:i['description']}
        d = {i['code']:i['material']}
        a.update(b)
        c.update(d)
    return a, c
desc, materiel = code_desc(codes)
print(materiel['G95'], desc['G95'], sources['G95'])
# will use this later
# Out:
# Plastic Cotton swabs Medical

# %%
def tops(df, n, column):
    return df.sort_values(by=column)[-n:]
dfZ = dfA[dfA.city == 'Zürich'].copy()

# %%
tops(dfZ, 20, 'pcs_per_m')
# Out:
#       code_id        date  pcs_per_m       id  length  \
# 3489      G27  2017-04-04      2.111   3490.0    63.0
# 10391     G79  2017-07-28      2.264  10392.0    53.0
# 11289     G27  2017-10-16      2.540  11290.0    50.0
# 11243     G27  2017-08-14      2.580  11244.0    50.0
# 10473     G27  2017-09-24      2.604  10474.0    53.0
# 3507      G27  2017-05-03      2.778   3508.0    63.0
# 4746      G27  2017-07-12      2.833   4747.0    42.0
# 11590     G27  2017-10-25      2.941  11591.0   101.0
# 10371    G208  2017-06-27      3.208  10372.0    53.0
# 11447     G27  2017-06-20      3.238  11448.0   101.0
# 11551     G27  2017-09-27      3.287  11552.0   101.0
# 11170     G27  2017-05-16      3.600  11171.0    50.0
# 11192     G27  2017-06-18      4.440  11193.0    50.0
# 10337     G27  2017-06-27      4.868  10338.0    53.0
# 11516     G27  2017-08-23      5.228  11517.0   101.0
# 11143     G27  2017-04-17      5.600  11144.0    50.0
# 10428     G27  2017-08-31      5.679  10429.0    53.0
# 4929      G27  2017-06-23      6.276   4930.0    29.0
# 10305     G27  2017-05-30      6.792  10306.0    53.0
# 10381     G27  2017-07-28      7.340  10382.0    53.0
#
#                                          location_id  quantity    city  \
# 3489   katzensee_regensdorfzuerichaffoltern_stueberj     133.0  Zürich
# 10391                        zuerichsee_zurich_kullg     120.0  Zürich
# 11289              zürichsee_wollishofen_langendorfm     127.0  Zürich
# 11243              zürichsee_wollishofen_langendorfm     129.0  Zürich
# 10473                        zuerichsee_zurich_kullg     138.0  Zürich
# 3507   katzensee_regensdorfzuerichaffoltern_stueberj     175.0  Zürich
# 4746                  limmat_zuerich_suterd&glauserp     119.0  Zürich
# 11590             Zürichsee-Feldeggstr-BänningerSand     297.0  Zürich
# 10371                        zuerichsee_zurich_kullg     170.0  Zürich
# 11447             Zürichsee-Feldeggstr-BänningerSand     327.0  Zürich
# 11551             Zürichsee-Feldeggstr-BänningerSand     332.0  Zürich
# 11170              zürichsee_wollishofen_langendorfm     180.0  Zürich
# 11192              zürichsee_wollishofen_langendorfm     222.0  Zürich
# 10337                        zuerichsee_zurich_kullg     258.0  Zürich
# 11516             Zürichsee-Feldeggstr-BänningerSand     528.0  Zürich
# 11143              zürichsee_wollishofen_langendorfm     280.0  Zürich
# 10428                        zuerichsee_zurich_kullg     301.0  Zürich
# 4929                 limmat_zürich_mortensena_meiera     182.0  Zürich
# 10305                        zuerichsee_zurich_kullg     360.0  Zürich
# 10381                        zuerichsee_zurich_kullg     389.0  Zürich
#
#         latitude  longitude  post  water       pop
# 3489   47.431128   8.492924  8046   lake  410126.0
# 10391  47.353957   8.550474  8008   lake  410126.0
# 11289  47.345890   8.536155  8038   lake  410126.0
# 11243  47.345890   8.536155  8038   lake  410126.0
# 10473  47.353957   8.550474  8008   lake  410126.0
# 3507   47.431128   8.492924  8046   lake  410126.0
# 4746   47.394539   8.513443  8005  river  410126.0
# 11590  47.359392   8.547368  8008   lake  410126.0
# 10371  47.353957   8.550474  8008   lake  410126.0
# 11447  47.359392   8.547368  8008   lake  410126.0
# 11551  47.359392   8.547368  8008   lake  410126.0
# 11170  47.345890   8.536155  8038   lake  410126.0
# 11192  47.345890   8.536155  8038   lake  410126.0
# 10337  47.353957   8.550474  8008   lake  410126.0
# 11516  47.359392   8.547368  8008   lake  410126.0
# 11143  47.345890   8.536155  8038   lake  410126.0
# 10428  47.353957   8.550474  8008   lake  410126.0
# 4929   47.400252   8.485411  8064  river  410126.0
# 10305  47.353957   8.550474  8008   lake  410126.0
# 10381  47.353957   8.550474  8008   lake  410126.0

# %%
def tops2(df, n=5, column='pcs_per_m'):
    return df.sort_values(by=column)[-n:]


dfZ.groupby('post').apply(tops2)
# Out:
#            code_id        date  pcs_per_m       id  length  \
# post
# 8001 7427     G156  2017-06-25      0.368   7428.0    19.0
#      7471      G27  2018-02-21      0.474   7472.0    19.0
#      7400      G27  2017-04-17      0.579   7401.0    19.0
#      7408      G27  2017-05-21      0.737   7409.0    19.0
#      7420      G27  2017-06-25      1.684   7421.0    19.0
# 8005 7361     G208  2018-02-28      0.594   7362.0    32.0
#      7213     G208  2017-04-09      0.781   7214.0    32.0
#      4716      G27  2017-06-14      0.905   4717.0    42.0
#      4673      G27  2017-04-10      0.952   4674.0    42.0
#      4746      G27  2017-07-12      2.833   4747.0    42.0
# 8008 10337     G27  2017-06-27      4.868  10338.0    53.0
#      11516     G27  2017-08-23      5.228  11517.0   101.0
#      10428     G27  2017-08-31      5.679  10429.0    53.0
#      10305     G27  2017-05-30      6.792  10306.0    53.0
#      10381     G27  2017-07-28      7.340  10382.0    53.0
# 8038 11289     G27  2017-10-16      2.540  11290.0    50.0
#      11243     G27  2017-08-14      2.580  11244.0    50.0
#      11170     G27  2017-05-16      3.600  11171.0    50.0
#      11192     G27  2017-06-18      4.440  11193.0    50.0
#      11143     G27  2017-04-17      5.600  11144.0    50.0
# 8041 7106      G27  2017-05-24      0.232   7107.0    99.0
#      7120      G27  2017-06-22      0.263   7121.0    99.0
#      7166     G204  2018-01-26      0.370   7167.0    27.0
#      7371      G27  2017-07-31      0.532   7372.0    47.0
#      7490      G27  2017-07-30      0.633   7491.0    30.0
# 8046 3614      G27  2017-11-06      0.825   3615.0    63.0
#      3544      G27  2017-07-05      0.841   3545.0    63.0
#      3597      G27  2017-10-05      0.952   3598.0    63.0
#      3489      G27  2017-04-04      2.111   3490.0    63.0
#      3507      G27  2017-05-03      2.778   3508.0    63.0
# 8064 4939     G156  2017-06-23      0.690   4940.0    29.0
#      4933      G67  2017-06-23      0.862   4934.0    29.0
#      4944     G178  2017-06-23      1.103   4945.0    29.0
#      4868      G27  2017-06-30      1.286   4869.0    35.0
#      4929      G27  2017-06-23      6.276   4930.0    29.0
#
#                                               location_id  quantity    city  \
# post
# 8001 7427                            Sihl_Zuerich_ScherfS       7.0  Zürich
#      7471                            Sihl_Zuerich_ScherfS       9.0  Zürich
#      7400                            Sihl_Zuerich_ScherfS      11.0  Zürich
#      7408                            Sihl_Zuerich_ScherfS      14.0  Zürich
#      7420                            Sihl_Zuerich_ScherfS      32.0  Zürich
# 8005 7361                  sihl_zuerich_eggerskoehlingera      19.0  Zürich
#      7213                  sihl_zuerich_eggerskoehlingera      25.0  Zürich
#      4716                  limmat_zuerich_suterd&glauserp      38.0  Zürich
#      4673                  limmat_zuerich_suterd&glauserp      40.0  Zürich
#      4746                  limmat_zuerich_suterd&glauserp     119.0  Zürich
# 8008 10337                        zuerichsee_zurich_kullg     258.0  Zürich
#      11516             Zürichsee-Feldeggstr-BänningerSand     528.0  Zürich
#      10428                        zuerichsee_zurich_kullg     301.0  Zürich
#      10305                        zuerichsee_zurich_kullg     360.0  Zürich
#      10381                        zuerichsee_zurich_kullg     389.0  Zürich
# 8038 11289              zürichsee_wollishofen_langendorfm     127.0  Zürich
#      11243              zürichsee_wollishofen_langendorfm     129.0  Zürich
#      11170              zürichsee_wollishofen_langendorfm     180.0  Zürich
#      11192              zürichsee_wollishofen_langendorfm     222.0  Zürich
#      11143              zürichsee_wollishofen_langendorfm     280.0  Zürich
# 8041 7106                          sihl_leimbach_kruegerm      23.0  Zürich
#      7120                          sihl_leimbach_kruegerm      26.0  Zürich
#      7166                          sihl_leimbach_kruegerm      10.0  Zürich
#      7371                      Sihl_zuerich_eichenbergerD      25.0  Zürich
#      7490                        sihl_zürich_himmelhebern      19.0  Zürich
# 8046 3614   katzensee_regensdorfzuerichaffoltern_stueberj      52.0  Zürich
#      3544   katzensee_regensdorfzuerichaffoltern_stueberj      53.0  Zürich
#      3597   katzensee_regensdorfzuerichaffoltern_stueberj      60.0  Zürich
#      3489   katzensee_regensdorfzuerichaffoltern_stueberj     133.0  Zürich
#      3507   katzensee_regensdorfzuerichaffoltern_stueberj     175.0  Zürich
# 8064 4939                 limmat_zürich_mortensena_meiera      20.0  Zürich
#      4933                 limmat_zürich_mortensena_meiera      25.0  Zürich
#      4944                 limmat_zürich_mortensena_meiera      32.0  Zürich
#      4868                          Limmat_Zuerich_WagnerC      45.0  Zürich
#      4929                 limmat_zürich_mortensena_meiera     182.0  Zürich
#
#              latitude  longitude  post  water       pop
# post
# 8001 7427   47.373149   8.532370  8001  river  410126.0
#      7471   47.373149   8.532370  8001  river  410126.0
#      7400   47.373149   8.532370  8001  river  410126.0
#      7408   47.373149   8.532370  8001  river  410126.0
#      7420   47.373149   8.532370  8001  river  410126.0
# 8005 7361   47.381898   8.538328  8005  river  410126.0
#      7213   47.381898   8.538328  8005  river  410126.0
#      4716   47.394539   8.513443  8005  river  410126.0
#      4673   47.394539   8.513443  8005  river  410126.0
#      4746   47.394539   8.513443  8005  river  410126.0
# 8008 10337  47.353957   8.550474  8008   lake  410126.0
#      11516  47.359392   8.547368  8008   lake  410126.0
#      10428  47.353957   8.550474  8008   lake  410126.0
#      10305  47.353957   8.550474  8008   lake  410126.0
#      10381  47.353957   8.550474  8008   lake  410126.0
# 8038 11289  47.345890   8.536155  8038   lake  410126.0
#      11243  47.345890   8.536155  8038   lake  410126.0
#      11170  47.345890   8.536155  8038   lake  410126.0
#      11192  47.345890   8.536155  8038   lake  410126.0
#      11143  47.345890   8.536155  8038   lake  410126.0
# 8041 7106   47.325436   8.519120  8041  river  410126.0
#      7120   47.325436   8.519120  8041  river  410126.0
#      7166   47.325436   8.519120  8041  river  410126.0
#      7371   47.339588   8.516697  8041  river  410126.0
#      7490   47.343055   8.518612  8041  river  410126.0
# 8046 3614   47.431128   8.492924  8046   lake  410126.0
#      3544   47.431128   8.492924  8046   lake  410126.0
#      3597   47.431128   8.492924  8046   lake  410126.0
#      3489   47.431128   8.492924  8046   lake  410126.0
#      3507   47.431128   8.492924  8046   lake  410126.0
# 8064 4939   47.400252   8.485411  8064  river  410126.0
#      4933   47.400252   8.485411  8064  river  410126.0
#      4944   47.400252   8.485411  8064  river  410126.0
#      4868   47.403496   8.477770  8064  river  410126.0
#      4929   47.400252   8.485411  8064  river  410126.0

# %%
def tops3(df, n=10, column='pcs_per_m'):
    return df.sort_values(by=column)[-n:]

z = dfZ.groupby(['date', 'post', 'location_id'])[['pcs_per_m']].sum()
z_10 = tops3(z)

# %%
plt.figure(figsize=(12,5));
z_10.plot.bar()
plt.show()

# %%
plt.figure(figsize=(12,5));
z.plot()
plt.show()

# %%
z.max()
# Out:
# pcs_per_m    18.984
# dtype: float64

# %%
dfZ.groupby(['post'])[['pcs_per_m']].max()
# Out:
#       pcs_per_m
# post
# 8001      1.684
# 8005      2.833
# 8008      7.340
# 8038      5.600
# 8041      0.633
# 8046      2.778
# 8064      6.276

# %%
quartiles = pd.cut(z.pcs_per_m, 4)

# %%
quartiles
# Out:
# date        post  location_id
# 2017-04-04  8046  katzensee_regensdorfzuerichaffoltern_stueberj    (3.5e-05, 4.76]
# 2017-04-09  8005  sihl_zuerich_eggerskoehlingera                   (3.5e-05, 4.76]
# 2017-04-10  8005  limmat_zuerich_suterd&glauserp                   (3.5e-05, 4.76]
# 2017-04-13  8041  sihl_leimbach_kruegerm                           (3.5e-05, 4.76]
#             8064  Limmat_Zuerich_JansenA                           (3.5e-05, 4.76]
# 2017-04-15  8008  zuerichsee_zurich_kullg                            (4.76, 9.501]
# 2017-04-17  8001  Sihl_Zuerich_ScherfS                             (3.5e-05, 4.76]
#             8038  zürichsee_wollishofen_langendorfm                  (4.76, 9.501]
# 2017-04-19  8008  Zürichsee-Feldeggstr-BänningerSand               (3.5e-05, 4.76]
# 2017-04-30  8046  katzenbach_zuerich_sanesim                       (3.5e-05, 4.76]
#             8064  Limmat_Zuerich_WagnerC                           (3.5e-05, 4.76]
# 2017-05-03  8046  katzensee_regensdorfzuerichaffoltern_stueberj    (3.5e-05, 4.76]
# 2017-05-04  8064  limmat_zürich_mortensena_meiera                  (3.5e-05, 4.76]
# 2017-05-11  8005  sihl_zuerich_eggerskoehlingera                   (3.5e-05, 4.76]
#             8064  Limmat_Zuerich_JansenA                           (3.5e-05, 4.76]
# 2017-05-16  8005  limmat_zuerich_suterd&glauserp                   (3.5e-05, 4.76]
#             8038  zürichsee_wollishofen_langendorfm                  (4.76, 9.501]
# 2017-05-21  8001  Sihl_Zuerich_ScherfS                             (3.5e-05, 4.76]
# 2017-05-24  8041  sihl_leimbach_kruegerm                           (3.5e-05, 4.76]
# 2017-05-25  8046  katzenbach_zuerich_sanesim                       (3.5e-05, 4.76]
# 2017-05-30  8008  zuerichsee_zurich_kullg                          (9.501, 14.243]
#             8064  Limmat_Zuerich_WagnerC                           (3.5e-05, 4.76]
# 2017-06-06  8046  katzensee_regensdorfzuerichaffoltern_stueberj    (3.5e-05, 4.76]
# 2017-06-14  8005  limmat_zuerich_suterd&glauserp                   (3.5e-05, 4.76]
# 2017-06-15  8064  Limmat_Zuerich_JansenA                           (3.5e-05, 4.76]
# 2017-06-18  8038  zürichsee_wollishofen_langendorfm                  (4.76, 9.501]
# 2017-06-20  8008  Zürichsee-Feldeggstr-BänningerSand                 (4.76, 9.501]
# 2017-06-22  8041  sihl_leimbach_kruegerm                           (3.5e-05, 4.76]
# 2017-06-23  8041  Sihl_zuerich_eichenbergerD                       (3.5e-05, 4.76]
#                   sihl_zürich_himmelhebern                         (3.5e-05, 4.76]
#                                                                         ...
# 2017-11-29  8046  katzenbach_zuerich_sanesim                       (3.5e-05, 4.76]
# 2017-11-30  8005  sihl_zuerich_eggerskoehlingera                   (3.5e-05, 4.76]
# 2017-12-08  8046  katzensee_regensdorfzuerichaffoltern_stueberj    (3.5e-05, 4.76]
# 2017-12-12  8038  zürichsee_wollishofen_langendorfm                (3.5e-05, 4.76]
# 2017-12-14  8064  Limmat_Zuerich_JansenA                           (3.5e-05, 4.76]
# 2017-12-21  8005  limmat_zuerich_suterd&glauserp                   (3.5e-05, 4.76]
# 2017-12-25  8008  zuerichsee_zurich_kullg                          (3.5e-05, 4.76]
#             8041  sihl_leimbach_kruegerm                           (3.5e-05, 4.76]
# 2017-12-31  8046  katzenbach_zuerich_sanesim                       (3.5e-05, 4.76]
#             8064  Limmat_Zuerich_WagnerC                           (3.5e-05, 4.76]
# 2018-01-09  8005  sihl_zuerich_eggerskoehlingera                   (3.5e-05, 4.76]
#             8046  katzensee_regensdorfzuerichaffoltern_stueberj    (3.5e-05, 4.76]
# 2018-01-17  8064  Limmat_Zuerich_JansenA                           (3.5e-05, 4.76]
# 2018-01-19  8038  zürichsee_wollishofen_langendorfm                (3.5e-05, 4.76]
# 2018-01-22  8041  Sihl_zuerich_eichenbergerD                       (3.5e-05, 4.76]
#                   sihl_zürich_himmelhebern                         (3.5e-05, 4.76]
# 2018-01-23  8008  Zürichsee-Feldeggstr-BänningerSand               (3.5e-05, 4.76]
# 2018-01-24  8008  zuerichsee_zurich_kullg                          (3.5e-05, 4.76]
#             8046  katzenbach_zuerich_sanesim                       (3.5e-05, 4.76]
# 2018-01-26  8041  sihl_leimbach_kruegerm                           (3.5e-05, 4.76]
# 2018-01-31  8005  limmat_zuerich_suterd&glauserp                   (3.5e-05, 4.76]
# 2018-02-10  8046  katzensee_regensdorfzuerichaffoltern_stueberj    (3.5e-05, 4.76]
# 2018-02-13  8038  zürichsee_wollishofen_langendorfm                (3.5e-05, 4.76]
# 2018-02-21  8001  Sihl_Zuerich_ScherfS                             (3.5e-05, 4.76]
# 2018-02-24  8005  limmat_zuerich_suterd&glauserp                   (3.5e-05, 4.76]
#             8008  Zürichsee-Feldeggstr-BänningerSand               (3.5e-05, 4.76]
# 2018-02-25  8041  sihl_leimbach_kruegerm                           (3.5e-05, 4.76]
# 2018-02-28  8005  sihl_zuerich_eggerskoehlingera                   (3.5e-05, 4.76]
#             8008  zuerichsee_zurich_kullg                          (3.5e-05, 4.76]
#             8046  katzenbach_zuerich_sanesim                       (3.5e-05, 4.76]
# Name: pcs_per_m, Length: 125, dtype: category
# Categories (4, interval[float64]): [(3.5e-05, 4.76] < (4.76, 9.501] < (9.501, 14.243] < (14.243, 18.984]]

# %%
def these_stats(grouped):
    return{'min':grouped.min(), 'max':grouped.max(), 'count':grouped.count(), 'mean':grouped.mean()}
cuts = z.pcs_per_m.groupby(quartiles)
cuts.apply(these_stats).unstack()
# Out:
#                   count     max       mean     min
# pcs_per_m
# (3.5e-05, 4.76]   110.0   4.693   1.149591   0.019
# (4.76, 9.501]      10.0   7.960   6.077100   4.851
# (9.501, 14.243]     4.0  12.924  12.124500  11.132
# (14.243, 18.984]    1.0  18.984  18.984000  18.984

# %%
bucks = len(z)/5
cuts_q = pd.qcut(z.pcs_per_m, 5)
group_q = z.pcs_per_m.groupby(cuts_q)
group_q.apply(these_stats).unstack()
# Out:
#                  count     max     mean    min
# pcs_per_m
# (0.018, 0.149]    25.0   0.143  0.07640  0.019
# (0.149, 0.653]    25.0   0.651  0.36908  0.151
# (0.653, 1.426]    25.0   1.402  1.04596  0.654
# (1.426, 3.027]    25.0   3.000  2.05860  1.461
# (3.027, 18.984]   25.0  18.984  6.63828  3.133
